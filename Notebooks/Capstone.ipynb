# %% [markdown]
# <div id="container" style="position:relative;">
# <div style="float:left"><h1> Data Preprocessing and Modeling</h1></div>
# <div style="position:relative; float:right"><img style="height:65px" src ="https://drive.google.com/uc?export=view&id=1EnB0x-fdqMp6I5iMoEBBEuxB_s7AmE2k" />
# </div>
# </div>

# %% [markdown]
# ### Importing the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import re

# %%
# Read in the data and refresh our memories
df = pd.read_csv('Gluten-free1.csv')

# %%
# Check
df.head(1)
# Out:
#                                          ingredients gluten-free?
# 0  ALL PURPOSE GF FLOUR (BROWN RICE FLOUR, POTATO...          yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 727 entries, 0 to 726
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ingredients   727 non-null    object
#  1   gluten-free?  727 non-null    object
# dtypes: object(2)
# memory usage: 11.5+ KB

# %%
ing_row = df["ingredients"]
ing_row.head()
# Out:
# 0    ALL PURPOSE GF FLOUR (BROWN RICE FLOUR, POTATO...
# 1    ALL PURPOSE GF FLOUR (BROWN RICE FLOUR, POTATO...
# 2    GLUTEN FREE FLOUR (TAPIOCA STARCH, BROWN RICE ...
# 3    GLUTEN FREE FLOUR (TAPIOCA, WHITE RICE, SORGHU...
# 4    GLUTEN FREE FLOUR (TAPIOCA STARCH, WHITE RICE ...
# Name: ingredients, dtype: object

# %% [markdown]
# ------

# %% [markdown]
# ### Cleaning the Data

# %%
# Define a regular expression pattern to match '()', '[]', and ','
pattern = r'[(),\[\]:]'

# Splitting the strings by the defined pattern and storing individual ingredients in a list
individual_ingredients = []
for row in ing_row:
    individual_ingredients.extend(ing_row)

# Printing the individual ingredients list
print(individual_ingredients)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Removing white space

# %%
clean_data_stripped = [item.strip() for item in individual_ingredients]

# %%
clean_data_stripped
# Out:
# ['ALL PURPOSE GF FLOUR (BROWN RICE FLOUR, POTATO FLOUR, TAPIOCA FLOUR, POTATO STARCH, WHITE RICE FLOUR, XANTHAN GUM), ORGANIC CANE SUGAR, VEGAN BUTTERY SPREAD [(OIL BLEND (PALM FRUIT, CANOLA, OLIVE), WATER, SALT, NATURAL FLAVOR, SUNFLOWER LECITHIN, LACTIC ACID, ANNATTO EXTRACT], ORGANIC BROWN SUGAR, VEGAN CHOCOLATE (ORGANIC SUGAR, CHOCOLATE, COCOA BUTTER, SOY LECITHIN, VANILLA BEAN), WATER, TAPIOCA SYRUP, LESS THAN 2% OF: PALM FRUIT OIL, PURE VANILLA EXTRACT (WATER, ALCOHOL 40%, VANILLA BEANS), CREAM OF TARTAR, SUNFLOWER LECITHIN, KOSHER SALT, BAKING SODA, GUAR GUM, KONJAC, XANTHAN GUM',
#  'ALL PURPOSE GF FLOUR (BROWN RICE FLOUR, POTATO FLOUR, TAPIOCA FLOUR, POTATO STARCH, WHITE RICE FLOUR, XANTHAN GUM), ORGANIC CANE SUGAR, GLUTEN FREE OATS, VEGAN BUTTERY SPREAD [(OIL BLEND (PALM FRUIT, CANOLA, OLIVE), WATER, SALT, NATURAL FLAVOR, SUNFLOWER LECITHIN, LACTIC ACID, ANNATTO EXTRACT], ORGANIC BROWN SUGAR, WATER, TAPIOCA SYRUP, PALM FRUIT OIL, BAKING SODA, PURE VANILLA EXTRACT (WATER, VANILLA BEAN, ALCOHOL 40%), SUNFLOWER LECITHIN, CREAM OF TARTAR, SPICE, KOSHER SALT, KONJAC, GUAR GUM, XANTHAN GUM',
#  'GLUTEN FREE FLOUR (TAPIOCA STARCH, BROWN RICE FLOUR), EGGS, SUGAR, CANOLA OIL, BROWN SUGAR, WATER, BLUEBERRIES, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, POTATO STARCH, MONOCALCIUM PHOSPHATE), LECITHIN, NATURAL FLAVOR, XANTHAN GUM, SALT, SUNFLOWER OIL.',
#  'GLUTEN FREE FLOUR (TAPIOCA, WHITE RICE, SORGHUM, CORN), PALM OIL, WATER, EGGS, SUGAR, SALT, XANTHAN GUM. BLUEBERRY  BLUEBERRIES, WATER, SUGAR, CORN SYRUP MODIFIED FOOD STARCH, VEGETABLE GUM, CITRIC ACID, VEGETABLE EXTRACT.',
#  'GLUTEN FREE FLOUR (TAPIOCA STARCH, WHITE RICE FLOUR, SORGHUM FLOUR, CORN STARCH), PALM OIL, WATER, EGGS, SUGAR, SALT, XANTHAN GUM, CHERRY FILLING (CHERRIES, WATER, SUGAR, CORN SYRUP, MODIFIED FOOD STARCH, VEGETABLE GUM, CITRIC ACID, VEGETABLE EXTRACT).',
#  "NON-GMO CONSTARCH, NON GMO POTATO STARCH, NON-GMO SORGHUM FLOUR, NON-GMO RICE FLOUR, NON-GMO POTATO FLOUR), WATER, NON-GMO CORN OIL, CANE SUGAR, DRY YEAST, SALT, XANTHAN GUM, EXTRA VIRGIN OLIVE OIL. SAUCE: VINE-RIPENED FRESH TOMATOES, SALT, CALCIUM CHLORIDE , NATURALLY DERIVED CITRIC ACID PIZZA SAUCE: TOMATOES PUREE, TOMATOES, CANOLA OIL, SALT, IMPORTED PECORINO CHEESE (PASTEURIZED SHEEP'S MILK, CHEESE CULTURES, SEA SALT, , RENNET), IMPORTED EXTRA VIRGIN OLIVE OIL, SPICES , GARLIC. WHOLE MILK MOZZARELLA CHEESE: PASTEURIZED MILK, CHEESE CULTURES, SALT, ENZYMES. ITALIAN SAUSAGE: PORK, SALT, NATURAL FLAVORING, DEXTROSE, GARLIC. NON GMO CORN OIL. PARMESAN CHEESE: PASTEURIZED PART-SKIM MILK, CHEESE CULTURES, SALT, ENZYMES). OREGANO.",
#  'GLUTEN FREE FLOUR (TAPIOCA, WHITE RICE, CORN, SOY), WATER, EGGS, PALM OIL, HONEY, BROWN SUGAR, XANTHAN GUM, SALT, DRY YEAST, APPLE CIDER VINEGAR, FLAX SEEDS.',
#  'ORGANIC POTATO, ALMOND FLOUR, CAGE-FREE EGG WHITES, SWEET POTATO FLOUR, SWEET POTATO JUICE, TAPIOCA FLOUR, CAGE-FREE EGGS, POTATO STARCH, SEA SALT, ANNATO SEED.',
#  'ALMOND FLOUR, CAGE-FREE EGGS, TAPIOCA FLOUR, XANTHAN GUM, SEA SALT.',
#  'BROWN RICE FLOUR, RICE FLOUR, POTATO STARCH, TAPIOCA FLOUR, BROWN SUGAR, NON-GMO CANOLA OIL, EGGS, POTATO FLOUR, YEAST, GUAR GUM, SEA SALT.',
#  'GLUTEN FREE FLOUR (WHITE RICE FLOUR, BROWN RICE FLOUR, POTATO STARCH, TAPIOCA FLOUR, XANTHAN GUM), VANILLA CREAM (AGAVE, NATURAL VANILLA EXTRACT, SUGAR, ORGANIC PALM OIL, CORN SYRUP, WATER), SUGAR, ORGANIC PALM OIL, WATER, EGG, COCOA (PROCESSED WITH ALKALI), NATURAL VANILLA EXTRACT, CREAM OF TARTAR, AGAVE SYRUP, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORNSTARCH, MONOCALCIUM PHOSPHATE), SALT, BAKING SODA.',
#  'GLUTEN FREE FLOUR (BROWN RICE FLOUR, POTATO STARCH, TAPIOCA FLOUR, XANTHAN GUM), SUGAR, ORGANIC PALM OIL, EGG, CHOCOLATE DIP (SUGAR, SOYBEAN OIL, COCOA, CHOCOLATE LIQUOR, SALT, VANILLA EXTRACT), BROWN SUGAR, COCONUT, VANILLA FLAVOR, AGAVE SYRUP, CREAM OF TARTAR, BAKING SODA, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORNSTARCH, MONOCALCIUM PHOSPHATE), SALT.',
#  'GLUTEN-FREE BREAD, BROWN RICE FLOUR, TAPIOCA STARCH, POTATO STARCH, CANOLA OIL, PSYLLIUM POWDER, EGG WHITES, EVAPORATED CANE SUGAR, TEFF FLOUR, SEA SALT, FLAX SEED, YEAST, XANTHAN GUM, GUAR GUM.   CHICKEN BREAST (CHICKEN BREAST, WATER, RICE STARCH, CHILIES, SALT, SUGAR, PAPRIKA), MONTEREY JACK CHEESE (PASTEURIZED MILK, CHEESE CULTURE, SALT, ENZYMES), ALFREDO SAUCE (CREAM CHEESE (PASTEURIZED, CULTURED MILK , CREAM, SALT, STABILIZER, BLACK BEANS (BLACK BEANS, WATER, SALT), CORN CHIPOTLE PUREE (WATER, VINEGAR, CHIPOTLE JALAPENO, TOMATO PASTE, SALT, RED CHILE FLAKES, SPICES, ONION POWDER, GARLIC POWDER), POWDERED CELLULOSE, CORN STARCH.',
#  'MARINARA SAUCE(DICED TOMATO [ TOMATOES, TOMATO JUICE, SALT, CITRIC ACID , CALCIUM CHLORIDE] , ONION, CHARDONNAY WINE, OLIVE CANOLA OIL BLEND, SUGAR, GARLIC, BASIL, SALT, BLACK PEPPER, RED PEPPER FLAKES, BAY LEAF), FILLING(RICOTTA CHEESE [ WHOLE MILK, WHEY, VINEGAR, SALT] , PARMESAN CHEESE [ PASTEURIZED MILK, CULTURE, SALT, ENZYMES] , EGG, BASIL, OREGANO), PASTA(BROWN RICE, RICE BRAN , WATER), LOW-MOISTURE PART-SKIM MOZZARELLA , PROVOLONE CHEESE(PASTEURIZED REDUCED-FAT MILK, PASTEURIZED MILK CHEESE CULTURE, SALT, ENZYMES, POWDERED CELLULOSE ADDED TO PREVENT CAKING, NATURAL SMOKE FLAVOR, NATAMYCIN ADDED AS A MOLD INHIBITOR).',
#  'MARINARA SAUCE(DICED TOMATO, ONION, WHITE WINE, OLIVE OIL, SUGAR, GARLIC, BASIL, SALT [  IODIZED] , RED PEPPER FLAKES, BLACK PEPPER, BAY LEAVES), DAIRY FREE CHEESE(FILTERED WATER, TAPIOCA ,/OR ARROWROOT FLOURS, NON-GMO EXPELLER PRESSED CANOLA ,/OR NON-GMO EXPELLER PRESSED SAFFLOWER OIL, COCONUT OIL, PEA PROTEIN, SALT, VEGAN NATURAL FLAVORS, INACTIVE YEAST, VEGETABLE GLYCERIN, XANTHUM GUM, CITRIC ACID [   FLAVOR] ), LASAGNA NOODLES(RICE, RICE BRAN, WATER), SPINACH, EGG, DRY BASIL, OREGANO(DRY GROUND)',
#  'WATER MODIFIED FOOD STARCH POTATO FLAKES SALT BROWN RICE FLOUR EGGS GUAR GUM XANTHAN GUM CAROB BEAN GUM MONO , DIGLYCERIDES LECITHIN RIBOFLAVIN',
#  'WATER, MODIFIED FOOD STARCH, POTATO FLAKES, SALT, BROWN RICE FLOUR, EGGS, GUAR GUM, XANTHAN GUM, CAROB BEAN GUM, MONO , DIGLYCERIDES, LECITHIN, RIBOFLAVIN,  WHOLE MILK RICOTTA CHEESE(SWEET WHEY, WHOLE MILK, SWEET CREAM, CULTURE, VINEGAR , SALT), ASIAGO CHEESE(PART SKIM MILK, CHEESE CULTURES, SALT, , ENZYMES), RICE FLOUR, SALT, HALF & HALF(MILK, CREAM), SALT, SPICE',
#  'CREAM CHEESE (PASTEURIZED MILK , CREAM, CHEESE CULTURE, SALT, STABILIZERS [CAROB BEAN ,/OR XANTHAN ,/OR GUAR GUMS]), SUGAR, EGG, RICE FLOUR, BUTTER, TAPIOCA FLOUR, POTATO STARCH, BAKING POWDER (SODIUM PYROPHOSPHATE, SODIUM BICARBONATE, SODIUM MONOCALCIUM PHOSPHATE), SALT, NATURAL FLAVORS, VANILLA, XANTHAN GUM',
#  'SUGAR, BUTTER (CREAM, NATURAL FLAVORING CHOCOLATE (COCOA MASS), GLUTEN FREE ALL PURPOSE MIX (RICE FLOUR, CORN STARCH, TAPIOCA DEXTRIN, XANTHAN GUM, RICE EXTRACT), PASTEURIZED EGGS (PASTEURIZED LIQUID EGG [WHOLE EGG, CITRIC ACID, 0.1% WATER ADDED AS A CARRIER  CITRIC ACID] ,/OR PASTEURIZED FRESH WHOLE EGG), VANILLA BEAN (SUGAR, WATER, VANILLA EXTRACT, VANILLA BEANS, GUM TRAGACANTH), SALT, PAN SPRAY (CANOLA OIL, ISOBUTENE, PROPANE, SOYA LECITHIN, DIMETHICONE)',
#  'CERTIFIED GLUTEN FREE OATS ,BROWN SUGAR ,DRIED CRANBERRIES ,(SUGAR ,GLYCERIN ,,CITRIC ACID ,SUNFLOWER OIL ,)CINNAMON ,GROUND FLAX ,SALT ,',
#  'CERTIFIED GLUTEN-FREE OATS, BROWN SUGAR, FREEZE-DRIED STRAWBERRIES, GROUND FLAX, SALT',
#  'RICE FLOUR, TAPIOCA STARCH, POTATO STARCH, NON-GMO CORN-STARCH ALUMINUM-FREE CORN-FREE BAKING POWDER (SODIUM ACID PYROPHOSPHATE, BAKING SODA, TAPIOCA STARCH, MONOCALCIUM PHOSPHATE), XANTHAN GUM (STABILIZER), SALT, NIACIN (VITAMIN B3), REDUCED IRON, CALCIUM CARBONATE, THIAMIN MONONITRATE (VITAMIN B1), RIBOFLAVIN (VITAMIN B2), FOLIC ACID (VITAMIN B9).',
#  'SUGAR, CHOCOLATE CHIPS (SUGAR, CHOCOLATE LIQUOR, COCOA BUTTER, SOY LECITHIN, VANILLA EXTRACT), COCOA POWDER PROCESSED WITH ALKALI, POTATO STARCH, WHITE RICE FLOUR, CORN STARCH, SALT, XANTHAN GUM.',
#  'CERTIFIED GLUTEN-FREE OATS, CASHEWS (SALT), DRIED CRANBERRIES (SUGAR, SUNFLOWER OIL), BROWN SUGAR, CANOLA OIL, HONEY, FLAX SEEDS, VANILLA',
#  'CERTIFIED GLUTEN-FREE OATS, BROWN SUGAR, FREEZE DRIED BANANAS, MAPLE SUGAR, FLAX MEAL, SALT.',
#  'GLUTEN-FREE BREAD: WATER, BROWN RICE FLOUR, TAPIOCA STARCH, POTATO STARCH, CANOLA OIL, PSYLLIUM POWDER, EGG WHITES, EVAPORATED CANE SUGAR, TEFF FLOUR, SEA SALT, FLAX SEED, YEAST, XANTHAN GUM, GUAR GUM.,   ROAST BEEF (BEEF, WATER, SALT), PROVOLONE CHEESE (PASTEURIZED MILK, CHEESE CULTURE, SALT, ENZYMES), ALFREDO SAUCE (CREAM CHEESE (PASTEURIZED, CULTURED MILK , CREAM, SALT, STABILIZER (XANTHAN GUM , OR CAROB BEAN , OR GUAR GUMS)), CARAMELIZED ONIONS (ONIONS, CANOLA OIL, SUGAR, BALSAMIC VINEGAR), POWDERED CELLULOSE, CORN STARCH.',
#  'GLUTEN-FREE FLOUR, TORTILLA (WHITE CORN MASA FLOUR , A TRACE OF LIME, WATER PREGELATINIZED RICE FOUR, POTATO FLOUR, HIGH OLEIC SAFFLOWER OIL, CORN STARCH, XANTHAN GUM), MOZZARELLA CHEESE (PASTEURIZED PART-SKIM MILK, CHEESE CULTURES, SALT ENZYMES), PIZZA SAUCE (VINE RIPENED FRESH TOMATOES, OLIVE OIL, SUNFLOWER OIL, SALT, SEASONINGS, GRANULATED GARLIC, CITRIC ACID), RICE, CHEDDAR CHEESE (PASTEURIZED MILK, CHEESE CULTURES, SALT, ENZYMES, ANNATTO COLOR), RICOTTA CHEESE (PASTEURIZED WHEY, PASTEURIZED MILK, VINEGAR, STABILIZER (MODIFIED FOOD STARCH, GUAR GUM, CARRAGEENAN), SALT), POWDERED CELLULOSE, MODIFIED FOOD STARCH, GARLIC SALT (SALT, GARLIC, GARLIC OIL), OREGANO.',
#  'GLUTEN-FREE FLOUR TORTILLA (WHITE CORN MASA FLOUR , A TRACE OF LIME, WATER, PREGELANTINIZED RICE FLOUR, POTATO FLOUR, HIGH OLEIC SAFFLOWER OIL, CORN STARCH, XANTHAN GUM), PIZZA SAUCE, (VINE RIPENED FRESH TOMATOES, OLIVE OIL, SUNFLOWER OIL, SALT, SEASONINGS, GRANULATED GARLIC, CITRIC ACID), MOZZARELLA CHEESE (PASTEURIZED PART-SKIM MILK, CHEESE CULTURES, SALT, ENZYMES), ITALIAN SAUSAGE (PORK, WATER, SPICES, SALT, SUGAR, FLAVORINGS), RICE POWDERED CELLULOSE, MODIFIED FOOD STARCH, GARLIC SALT (SALT, GARLIC, CALCIUM SILICATE, GARLIC OIL).',
#  'REFRIED BEANS (BEANS, WATER, CANOLA OIL, SALT), RICE, CHEDDAR CHEESE (PASTEURIZED MILK, CHEESE CULTURES, SALT, ENZYMES, ANNATTO COLOR), SALSA (TOMATOES, TOMATO JUICE (WATER, TOMATO CONCENTRATE, SALT, VITAMIN C), ONIONS, BELL PEPPERS, PEPPERS, PARSLEY, GARLIC, CILANTRO, APPLE CIDER VINEGAR, SPICES, SEA SALT, HERBS), CORN, SOUR CREAM (GRADE A CULTURED CREAM (MILK), ENZYME), GARLIC SALT (GARLIC, SALT, GARLIC OIL). GLUTEN-FREE TORTILLA: WATER, WHITE CORN MASA FLOUR (TRACE OF LIME), PREGELATINIZED RICE FLOUR, POTATO STARCH, HIGH OLEIC SAFFLOWER OIL, CORN STARCH , XANTHAN GUM.',
#  'GLUTEN-FREE FLOUR TORTILLA(WHITE CORN MASA FLOUR , A TRACE OF LIME, WATER, PREGELATINIZED RICE FLOUR, POTATO FLOUR, HIGH OLEIC SAFFLOWER OIL, CORN STARCH, XANTHAN GUM , CULTURED DEXTROSE), REFRIED BEANS(BEANS, WATER, CANOLA OIL, SALT), RICE, SALSA(TOMATOES, TOMATO JUICE, (WATER, TOMATO CONCENTRATE, SALT, VITAMIN C), ONIONS, BELL PEPPERS, PEPPERS, PARSLEY, GARLIC, CILANTRO, APPLE CIDER VINEGAR, SPICES, SEA SALT, HERBS), TOFU(WATER, SOYBEANS, CALCIUM SULFATE), GMO FREE CORN, GARLIC SALT(GARLIC, SALT, GARLIC OIL).',
#  'GLUTEN FREE BREAD: WATER, BROWN RICE FLOUR, TAPIOCA STARCH, POTATO STARCH, CANOLA OIL, PSYLLIUM POWDER, EGG WHITES, ORGANIC EVAPORATED CANE SUGAR, TEFF FLOUR, SEA SALT, FLAX SEED, YEAST, XANTHAN GUM, GUAR GUM.   UNCURED HICKORY SMOKED HAM. NO NITRATES OR NITRATES ADDED EXCEPT THOSE NATURALLY OCCURRING IN SEA SALT, NATURAL FLAVORINGS , CELERY POWDER. (HAM, WATER, HONEY, SEA SALT, NATURAL FLAVORINGS, TURBINADO SUGAR, CELERY POWDER, SODIUM CARBONATE), ALFREDO SAUCE (CREAM CHEESE (PASTEURIZED, CULTURED MILK , , CREAM, SALT, STABILIZER (XANTHAN GUM , OR CAROB BEAN , OR GUAR GUMS)), PASTEURIZED CREAM (MILK), UNSALTED BUTTER (CREAM, (MILK), NATURAL FLAVOR), SEA SALT, GARLIC POWDER, BLACK PEPPER), CHEDDAR CHEESE PASTEURIZED MILK, CHEESE CULTURE, SALT, ENZYMES, ANNATTO (COLOR)), MONTEREY JACK CHEESE (PASTEURIZED MILK, CHEESE CULTURE, SALT, ENZYMES), POWDERED CELLULOSE, CORN STARCH.',
#  'MARINARA SAUCE (DICED TOMATO [TOMATOES, TOMATO JUICE, SALT, CITRIC ACID , CALCIUM CHLORIDE], ONION, CHARDONNAY WINE, OLIVE CANOLA OIL BLEND, SUGAR, GARLIC, BASIL, SALT, BLACK PEPPER, RED PEPPER FLAKES, BAY LEAF), FILLING (RICOTTA CHEESE [WHOLE MILK, WHEY, VINEGAR, SALT], PARMESAN CHEESE [PASTEURIZED MILK, CULTURE, SALT, ENZYMES], EGG, BASIL, OREGANO), PASTA (BROWN RICE, RICE BRAN , WATER), SPINACH , LOW-MOISTURE PART-SKIM MOZZARELLA , PROVOLONE CHEESE (PASTEURIZED REDUCED-FAT MILK, PASTEURIZED MILK CHEESE CULTURE, SALT, ENZYMES, POWDERED CELLULOSE ADDED TO PREVENT CAKING, NATURAL SMOKE FLAVOR, NATAMYCIN ADDED AS A MOLD INHIBITOR).',
#  "WHOLE GRAIN BROWN RICE FLOUR, MODIFIED TAPIOCA STARCH, EGGS, XANTHAN GUM, SALT, WATER.  WHOLE MILK RICOTTA CHEESE (SWEET WHEY, WHOLE MILK, SWEET CREAM, CULTURE, VINEGAR , SALT), ASIAGO (PART SKIM MILK, CHEESE CULTURES, SALT, , ENZYMES), ROMANO CHEESE (PASTEURIZED COW'S MILK, CHEESE CULTURES, SALT, , ENZYMES), PARMESAN CHEESE (PASTEURIZED PART-SKIM COW'S MILK, CHEESE CULTURES, SALT , ENZYMES), DEHYDRATED POTATOES (100% POTATOES) SALT, SPICES.",
#  'GLUTEN FREE ALL PURPOSE MIX (RICE FLOUR, CORN STARCH, TAPIOCA DEXTRIN, XANTHAN GUM, RICE EXTRACT), WATER, PASTEURIZED EGGS (PASTEURIZED LIQUID EGG [WHOLE EGG, CITRIC ACID, 0.1% WATER ADDED AS A CARRIER  CITRIC ACID] ,/OR PASTEURIZED FRESH WHOLE EGG), SUGAR, OLIVE OIL, YEAST (SORBITAN MONOSTEARATE ,/OR ASCORBIC ACID), SALT, APPLE CIDER VINEGAR (DILUTED WITH WATER 0.4% ACIDITY). TOPPING: LOW-MOISTURE PART-SKIM MOZZARELLA , PROVOLONE CHEESE (PASTEURIZED REDUCED-FAT MILK, PASTEURIZED MILK CHEESE CULTURE, SALT, ENZYMES, POWDERED CELLULOSE ADDED TO PREVENT CAKING, NATURAL SMOKE FLAVOR, NATAMYCIN ADDED AS A MOLD INHIBITOR). SAUCE: ALL PURPOSE GROUND TOMATO WITH ADDED EXTRA HEAVY PUREE (UNPEELED GROUND TOMATO, EXTRA HEAVY TOMATO PUREE, SALT), OLIVE OIL, SUGAR, SALT, GARLIC, BLACK PEPPER, RED PEPPER FLAKES, DRY BASIL, OREGANO.',
#  "WHOLE GRAIN BROWN RICE FOUR, MODIFIED TAPIOCA STARCH, EGG, XANTHAN GUM, WATER.  WHOLE MILK RICOTTA CHEESE (SWEET WHEY, WHOLE MILK, SWEET CREAM, CULTURE, VINEGAR , SALT), PORTOBELLO MUSHROOMS, PARMESAN CHEESE (PASTEURIZED PART-SKIM COW'S MILK, CHEESE CULTURES, SALT, , ENZYMES), ROMANO CHEESE (PASTEURIZED COW'S MILK, CHEESE CULTURES, SALT, , ENZYMES), DEHYDRATED POTATOES (100% POTATOES), NATURAL MUSHROOM BASE (SAUTEED MUSHROOM, SEA SALT, BUTTER (SWEET CREAM, ANNATTO), YEAST EXTRACT, NATURAL FLAVORINGS, SPICE & VEGETABLE EXTRACT), SALT, , SPICES.",
#  'MARINARA SAUCE (DICED TOMATO, ONION, WHITE WINE, OLIVE OIL, SUGAR, GARLIC, BASIL, SALT [IODIZED], RED PEPPER FLAKES, BLACK PEPPER, BAY LEAVES), DAIRY FREE CHEESE (FILTERED WATER, TAPIOCA ,/OR ARROWROOT FLOURS, NON-GMO EXPELLER PRESSED CANOLA ,/OR NON-GMO EXPELLER PRESSED SAFFLOWER OIL, COCONUT OIL, PEA PROTEIN, SALT, VEGAN NATURAL FLAVORS, INACTIVE YEAST, VEGETABLE GLYCERIN, XANTHUM GUM, CITRIC ACID [ FLAVOR}), LASAGNA NOODLES (RICE, RICE BRAN, WATER), EGG, DRY BASIL, OREGANO (DRY GROUND).',
#  "WHOLE GRAIN BROWN RICE FLOUR, MODIFIED TAPIOCA STARCH, EGGS, XANTHAN GUM, SALT, WATER.  WHOLE MILK RICOTTA CHEESE (SWEET WHEY, WHOLE MILK, SWEET CREAM, CULTURE, VINEGAR , SALT), SPINACH, ASIAGO CHEESE (PASTEURIZED PART-SKIM COW'S MILK, CHEESE CULTURES, SALT , ENZYMES), PARMESAN CHEESE (PASTEURIZED PART-SKIM COW'S MILK, CHEESE CULTURES, SALT , ENZYMES), ROMANO CHEESE (PASTEURIZED COW'S MILK, CHEESE CULTURES, SALT, , ENZYMES), DEHYDRATE POTATOES (100% POTATOES), SALT, SPICES.",
#  'SUGAR, WHITE RICE FLOUR, POTATO STARCH, COCOA POWDER PROCESSED WITH ALKALI, TAPIOCA STARCH, SODIUM BICARBONATE, SALT, GUAR GUM, SODIUM ACID PYROPHOSPHATE, MONOCALCIUM PHOSPHATE.',
#  'WHITE RICE FLOUR, BROWN RICE FLOUR, POTATO STARCH, SKIM MILK, WHEY, CORN STARCH, CANE SUGAR, GUAR GUM, YEAST, SALT.',
#  'GLUTEN-FREE OATS.',
#  'CORN MEAL, WHITE RICE FLOUR, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORN STARCH, MONOCALCIUM PHOSPHATE, CALCIUM SULFATE), SALT.',
#  'BROWN RICE FLOUR, POTATO STARCH, TAPIOCA STARCH, SUGAR, SALT, XANTHAN GUM.',
#  'TAPIOCA STARCH, SUGAR, CHOCOLATE CHIPS (SUGAR, CHOCOLATE LIQUOR, COCOA BUTTER, SOY LECITHIN, VANILLA EXTRACT), POTATO STARCH, BROWN RICE FLOUR, SODIUM BICARBONATE, XANTHAN GUM, SALT, MODIFIED CELLULOSE.',
#  'WHITE RICE FLOUR, POTATO STARCH, TAPIOCA STARCH, PEA HULL FIBER, ACACIA GUM, RICE PROTEIN.',
#  'SUGAR, RICE FLOUR, COCOA PROCESSED WITH ALKALI, POTATO STARCH, TAPIOCA STARCH, PURE VANILLA POWDER, SALT, ALUMINUM-FREE CORN-FREE BAKING POWDER (SODIUM ACID PYROPHOSPHATE, BAKING SODA, TAPIOCA STARCH, MONOCALCIUM PHOSPHATE), CELLULOSE GUM (STABILIZER).',
#  'GLUTEN-FREE FLOUR BLEND (RICE FLOUR, TAPIOCA STARCH, POTATO STARCH), SUGAR, VANILLA POWDER, CELLULOSE GUM (STABILIZER), ALUMINUM-FREE CORN-FREE BAKING POWDER (SODIUM ACID PYROPHOSPHATE, BAKING SODA, TAPIOCA STARCH, MONOCALCIUM PHOSPHATE), SALT.',
#  'WATER, WHOLE GRAIN BROWN RICE FLOUR, CORN STARCH, TAPIOCA STARCH, EGGS, RAISINS, CANE SUGAR, CORN DEXTRIN, NON GMO CANOLA OIL, CINNAMON, POTATO FLOUR, HONEY, BAKING POWDER, XANTHAN GUM, YEAST, SALT, RICE BRAN, VINEGAR, ENZYMES (CALCIUM SULFATE , ENZYMES).',
#  'WATER, BROWN RICE FLOUR, TAPIOCA STARCH, POTATO STARCH, EXPELLER PRESSED CANOLA OIL, MADE FROM NON-GENETICALLY MODIFIED SEED, PSYLLIUM POWDER, EGG WHITES, EVAPORATED CANE SUGAR, PARMESAN CHEESE (PASTEURIZED MILK, CHEESE CULTURE, SALT, ENZYMES, MAY CONTAIN ONE OR MORE OF THE FOLLOWING ADDED TO PREVENT CAKING; POWDERED CELLULOSE, POTATO STARCH OR CORN STARCH), ASIAGO CHEESE (PASTEURIZED MILK, CHEESE CULTURES, SALT, ENZYMES, POWDERED CELLULOSE ADDED TO PREVENT CAKING), YEAST, TEFF FLOUR, FLAX SEED. SALT, CULTURED DEXTROSE, XANTHAN GUM, GUAR GUM, CITRIC ACID',
#  'WATER, WHOLE GRAIN BROWN RICE FLOUR, CORN STARCH, TAPIOCA STARCH, EGGS, CORN DEXTRIN, CANE SUGAR, NON-GMO CANOLA OIL, HONEY, FLAX SEEDS, SUNFLOWER SEEDS, PUMPKIN SEEDS, POTATO FLOUR, BAKING POWDER, YEAST, XANTHAN GUM, RICE BRAN, SALT, GROUND FLAX SEEDS, SESAME SEEDS, CHIA SEEDS, MILLET SEEDS, HULLED HEMP SEEDS, VINEGAR, ENZYMES (CALCIUM SULFATE , ENZYMES).',
#  'CERTIFIED GLUTEN-FREE OATS, ALMONDS (ALMONDS, CANOLA OIL ,/OR SAFFLOWER OIL), BROWN CANE SUGAR, RAISINS (RAISINS, GLYCERIN, VEGETABLE OIL (CANOLA OR SUNFLOWER OIL)), ORGANIC HONEY, CANOLA OIL, FLAX SEEDS, CONTAINS LESS THAN 0.5% VANILLA EXTRACT , CINNAMON.',
#  'CERTIFIED GLUTEN-FREE OATS, ALMONDS (ALMONDS, CANOLA OIL ,/OR SAFFLOWER OIL), BROWN CANE SUGAR, ORGANIC HONEY, APPLES, CANOLA OIL, FLAX SEEDS, CONTAINS LESS THAN 0.5% VANILLA EXTRACT , CINNAMON.',
#  'CERTIFIED GLUTEN-FREE OATS, CASHEWS (CASHEWS, CANOLA OIL, SALT), BROWN CANE SUGAR, CRANBERRIES (CRANBERRIES, SUGAR, GLYCERIN, CITRIC ACID, SUNFLOWER OIL), ORGANIC HONEY, CANOLA OIL, FLAX SEEDS, CONTAINS LESS THAN 0.5% VANILLA EXTRACT.',
#  'CERTIFIED GLUTEN-FREE OATS, BROWN CANE SUGAR, FREEZE DRIED STRAWBERRIES, FREEZE-DRIED WILD BLUEBERRIES, GROUND FLAX, SEA SALT.',
#  'SUGAR, CHOCOLATE CHIPS (SUGAR, CHOCOLATE LIQUOR, COCOA BUTTER, SOY LECITHIN, VANILLA EXTRACT), COCOA POWDER PROCESSED WITH ALKALI, WHITE FUDGE CHIPS (SUGAR, PALM KERNEL , PALM OIL, WHEY POWDER, NONFAT MILK POWDER, SOY LECITHIN, NATURAL FLAVOR), POTATO STARCH, WHITE RICE FLOUR, CORN STARCH, NATURAL FLAVOR, SALT, XANTHAN GUM.',
#  'CERTIFIED GLUTEN-FREE OATS, BROWN CANE SUGAR, GROUND FLAX, SEA SALT',
#  'WHITE RICE FLOUR, SUGAR, POTATO STARCH, FLOUR MIX (PEA FIBER, PEA PROTEIN, SORGHUM FLOUR, INULIN), BAKING POWDER (SODIUM ACID PYROPHOSPHATE, CALCIUM SULFATE), SALT, SODIUM BICARBONATE, XANTHAN GUM.',
#  'BROWN RICE FLOUR, WHITE RICE FLOUR, SKIM MILK POWDER, SAFFLOWER MIX (SAFFLOWER OIL WITH TOCOPHEROLS, NONFAT MILK, DISODIUM PHOSPHATE, NATURAL FLAVOR), SUGAR, EGGS, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORN STARCH, MONOCALCIUM PHOSPHATE, CALCIUM SULFATE), SALT, XANTHAN GUM.',
#  'RAISINS, GLUTEN FREE OATS, TAPIOCA FLOUR, BUTTER, BROWN SUGAR, WHOLE GRAIN SORGHUM FLOUR, PURE CANE SUGAR, EGGS, BAKING SODA, PURE VANILLA EXTRACT, NON ALUMINUM BAKING POWDER, SALT',
#  'SULFITE FREE COCONUT, PURE CANE SUGAR, EGG WHITES, SALT, PURE VANILLA EXTRACT, CREAM OF TARTAR',
#  'PEANUT BUTTER (NATURAL FRESH GROUND PEANUTS, SALT), PURE CANE SUGAR, BUTTER, TAPIOCA FLOUR, WHOLE GRAIN SORGHUM FLOUR, EGGS, CREAM OF TARTAR, PURE VANILLA EXTRACT, BAKING SODA, SALT',
#  'ALMOND PASTE, (BLANCHED ALMONDS, PURE CANE SUGAR), PURE CANE SUGAR, ALMONDS, EGG WHITES, CREAM OF TARTAR',
#  'PURE CANE SUGAR, TAPIOCA FLOUR, WHOLE GRAIN SORGHUM FLOUR, BUTTER, EGGS, CREAM OF TARTAR, PURE VANILLA EXTRACT, BAKING SODA, SALT, CINNAMON',
#  'SULFITE FREE COCONUT, PURE CANE SUGAR, COCOA POWDER, EGG WHITES, SALT, PURE VANILLA EXTRACT, CREAM OF TARTAR',
#  'PURE CANE SUGAR, TAPIOCA FLOUR, WHOLE GRAIN SORGHUM FLOUR, BUTTER, EGGS, MOLASSES, CINNAMON, SPICES, CREAM OF TARTAR, PURE VANILLA EXTRACT, BAKING SODA, SALT, PEPPER',
#  'BROWN RICE FLOUR, WHITE RICE FLOUR, POTATO STARCH, TAPIOCA FLOUR, BROWN SUGAR, NON-GMO CANOLA OIL, EGGS, POTATO FLOUR, GARLIC POWDER, SALT, YEAST, GUAR GUM, HERBS , SPICES.',
#  'ALMOND FLOUR, CHOCOLATE MORSELS (EVAPORATED CANE JUICE, NATURAL CHOCOLATE LIQUOR (NON-ALCOHOLIC), NON-DAIRY COCOA BUTTER), ORGANIC GRADE B VERMONT MAPLE SYRUP, ARROWROOT FLOUR, ORGANIC UNREFINED COCONUT OIL, ORGANIC SEA SALT, ORGANIC VANILLA EXTRACT, BAKING SODA.',
#  'CERTIFIED GLUTEN-FREE OATS, BROWN SUGAR, DRIED APPLES, FLAX MEAL, CINNAMON, SALT.',
#  'GLUTEN FREE FLOUR (TAPIOCA, WHITE RICE, CORN, SORGHUM), PALM OIL, WATER, EGGS, SUGAR, SALT, XANTHAN GUM, PUMPKIN FILLING (PUMPKIN, EGGS, WATER, BROWN SUGAR, CORN STARCH, SUGAR, CANOLA OIL, PURE VANILLA EXTRACT, CINNAMON, GINGER, CLOVES, AGAR, CALCIUM CARBONATE, CALCIUM SULFATE).',
#  'CERTIFIED GLUTEN-FREE OATS, BROWN CANE SUGAR, CRANBERRIES (SUGAR, GLYCERINE, CITRIC ACID, SUNFLOWER OIL), APPLES, WALNUTS, GROUND FLAX, CINNAMON, SEA SALT',
#  'CERTIFIED GLUTEN-FREE OATS, BROWN CANE SUGAR, GOLDEN RAISINS, BROWN RAISINS (GLYCERINE, SUNFLOWER OIL OR CANOLA OIL), ALMONDS, GROUND FLAX, SEA SALT',
#  'WHITE RICE FLOUR, BROWN RICE FLOUR, CORN FLOUR, QUINOA FLOUR, MONO , DIGLYCERIDES.',
#  'WATER, BROWN RICE FLOUR, CORN STARCH, TAPIOCA STARCH, EGGS, CORN DEXTRIN, YEAST, XANTHAN GUM, SALT, GELATIN, VINEGAR, POTATO FLOUR, SUGAR, SEASONINGS (MARJORAM, THYME, ROSEMARY, SAVORY, SAGE, OREGANO , BASIL), OLIVE OIL, NON-GMO CANOLA OIL. TOPPINGS: SAUCE (TOMATOES, CORN OIL, SALT, SPICES, POWDERED GARLIC, SUGAR), MOZZARELLA CHEESE (CULTURED PASTEURIZED MILK, SALT, ENZYMES), PROVOLONE CHEESE (CULTURED PASTEURIZED MILK, SALT, ENZYMES) , ANTICAKING AGENT.',
#  'WATER, BROWN RICE FLOUR, CORN STARCH, TAPIOCA STARCH, EGGS, CORN DEXTRIN, YEAST, XANTHAN GUM, SALT, GELATIN, VINEGAR, POTATO FLOUR, SUGAR, SEASONINGS (MARJORAM, THYME, ROSEMARY, SAVORY, SAGE, OREGANO, , BASIL), OLIVE OIL, NON-GMO CANOLA OIL. TOPPINGS: SAUCE (TOMATOES, CORN OIL, SALT, SPICES, POWDERED GARLIC, SUGAR), MOZZARELLA CHEESE (CULTURED PASTEURIZED MILK, SALT, ENZYMES), PROVOLONE CHEESE (CULTURED PASTEURIZED MILK, SALT, ENZYMES) , ANTICAKING AGENT, ITALIAN SAUSAGE: PORK, WATER, SPICES, SALT, DEXTROSE, SODIUM PHOSPHATES, SUGAR, GARLIC POWDER.',
#  'WATER, BROWN RICE FLOUR, CORN STARCH, TAPIOCA STARCH, EGGS, CORN DEXTRIN, YEAST, XANTHAN GUM, SALT, GELATIN, VINEGAR, POTATO FLOUR, SUGAR, SEASONINGS (MARJORAM, THYME, ROSEMARY, SAVORY, SAGE, OREGANO , BASIL), OLIVE OIL, NON-GMO CANOLA OIL. TOPPINGS: SAUCE (TOMATOES, CORN OIL, SALT, SPICES, POWDERED GARLIC, SUGAR) MOZZARELLA CHEESE (CULTURED PASTEURIZED MILK, SALT, ENZYMES), PROVOLONE CHEESE (CULTURED PASTEURIZED MILK, SALT, ENZYMES) , ANTICAKING AGENT, UNCURED PEPPERONI NO NITRITES OR NITRATES ADDED, PORK, BEEF, SALT, CONTAINS 2% OR LESS OF WATER, SPICE SEASONINGS (CANE SUGAR, NATURAL FLAVOR), SEASONINGS (EXTRACTIVES OF PAPRIKA, NATURAL SPICE EXTRACTIVES), LACTIC ACID STARTER CULTURE.',
#  'GLUTEN FREE FLOUR (CORN, WHITE RICE, TAPIOCA), PALM OIL, SUGAR, EGGS, WATER, CANOLA OIL, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORN STARCH, MONOCALCIUM PHOSPHATE), XANTHAN GUM, SALT, PURE VANILLA EXTRACT, SUNFLOWER LECITHIN, DONUT SUGAR (DEXTROSE, CORN STARCH).',
#  'POTATO STARCH, BROWN RICE FLOUR, SUGAR, TAPIOCA STARCH, YEAST, MODIFIED CELLULOSE, SALT.',
#  'WATER, WHOLE GRAIN BROWN RICE FLOUR, TAPIOCA STARCH, CORN STARCH, EGGS, CORN DEXTRIN, SUGAR, NON-GMO CANOLA OIL, POTATO FLOUR, HONEY, BAKING POWDER, YEAST, RICE BRAN, XANTHAN GUM, SALT, VINEGAR, ENZYMES (CALCIUM SULFATE & ENZYMES).',
#  'WATER, WHOLE GRAIN BROWN RICE FLOUR, TAPIOCA STARCH, CORN STARCH, WHOLE GRAIN MILLET FLOUR, WHOLE GRAIN SORGHUM FLOUR, WHOLE GRAIN TEFF FLOUR, EGG WHITES, CORN DEXTRIN, CANE SUGAR, NON-GMO CANOLA OIL, POTATO FLOUR, HONEY, RICE BRAN EXTRACT, SUNFLOWER SEEDS, SESAME SEEDS, WHOLE GRAIN QUINOA, WHOLE GRAIN TEFF, GROUND FLAX SEED, FLAX SEEDS, WHOLE GRAIN MILLET, WHOLE GRAIN AMARANTH FLOUR, HEMP SEEDS, BAKING POWDER, YEAST, XANTHAN GUM, SALT, VINEGAR, ENZYMES (CALCIUM SULFATE & ENZYMES).',
#  'WATER, WHOLE GRAIN BROWN RICE FLOUR, TAPIOCA STARCH, CORN STARCH, EGGS, CORN DEXTRIN, SUGAR, NON-GMO CANOLA OIL, POTATO FLOUR, HONEY, BAKING POWDER, YEAST, RICE BRAN, XANTHAN GUM, GLUTEN FREE NATURAL FLAVORS, SALT, VINEGAR, CARAWAY SEEDS, ENZYMES (CALCIUM SULFATE & ENZYMES).',
#  'CERTIFIED GLUTEN-FREE OATS.',
#  'MARINARA (DICED TOMATO [TOMATOES, TOMATO JUICE, SALT, CITRIC ACID, , CALCIUM CHLORIDE], ONION, CHARDONNAY WINE, OLIVE CANOLA OIL BLEND, SUGAR, GARLIC, BASIL, SALT, BLACK PEPPER, RED PEPPER FLAKES, BAY LEAF), FUSILLI PASTA (BROWN RICE, WATER), BONELESS SKINLESS CHICKEN BREAST, (SEASONED BREADING [GLUTEN FREE ALL PURPOSE MIX (RICE FLOUR, CORN STARCH, TAPIOCA DEXTRIN, XANTHAN GUM, RICE EXTRACT), WATER, PASTEURIZED EGGS (PASTEURIZED LIQUID EGG [WHOLE EGG, CITRIC ACID], ,/OR PASTEURIZED FRESH WHOLE EGG), OLIVE OIL, SUGAR, YEAST (SORBITAN MONOSTEARATE ,/OR ASCORBIC ACID), SALT, APPLE CIDER VINEGAR, PAN SPRAY (CANOLA OIL, ISOBUTENE, PROPANE, SOYA LECITHIN, DIMETHICONE), GARLIC, SALT, BLACK PEPPER, PAPRIKA], PASTEURIZED LIQUID EGG, GLUTEN FREE ALL PURPOSE MIX [RICE FLOUR, CORN STARCH, TAPIOCA DEXTRIN, XANTHAN GUM, RICE EXTRACT], SALT, WHITE PEPPER), PARSLEY.',
#  'GLUTEN FREE FLOUR (BROWN RICE FLOUR, POTATO STARCH, TAPIOCA FLOUR, XANTHAN GUM), PALM OIL, CHOCOLATE CHIPS (SUGAR, COCOA POWDER (PROCESSED WITH ALKALI), CHOCOLATE LIQUOR, SOY LECITHIN, VANILLA EXTRACT), SUGAR, BROWN SUGAR, EGG, VANILLA, BAKING SODA, AGAVE SYRUP, CREAM OF TARTAR, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORNSTARCH, MONOCALCIUM PHOSPHATE), SALT.',
#  'FLOUR (OAT FLOUR ,/OR COCONUT FLOUR), BROWN SUGAR, CHOCOLATE CHIPS (SUGAR, UNSWEETENED CHOCOLATE, COCOA BUTTER, SOY LECITHIN (AN EMULSIFIER), NATURAL VANILLA EXTRACT), MARGARINE (CANOLA ,/OR SOYBEAN OIL, PALM OIL , PALM KERNEL OILS, WATER, SALT, SOY LECITHIN (AN EMULSIFIER), MONO , DIGLYCERIDES, SODIUM BENZOATE (PRESERVATIVE), ARTIFICIAL BUTTER FLAVOR, BETA CAROTENE (COLOR), VITAMIN A PALMITATE), SHORTENING (PALM OIL), EGG, SUGAR, BAKING SODA, SEA SALT, VANILLA EXTRACT (WATER, ALCOHOL, SUGAR, VANILLA BEAN EXTRACTIVES).',
#  'GLUTEN FREE FLOUR (BROWN RICE FLOUR, POTATO STARCH, TAPIOCA FLOUR, XANTHAN GUM), SUGAR, ORGANIC PALM OIL, EGG, CHOCOLATE CHIPS (SUGAR, COCOA POWDER (PROCESSED WITH ALKALI), CHOCOLATE LIQUOR, SOY LECITHIN, VANILLA EXTRACT), BROWN SUGAR, NATURAL VANILLA EXTRACT, AGAVE, CREAM OF TARTAR, BAKING SODA, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORNSTARCH, MONOCALCIUM PHOSPHATE), SALT.',
#  'GLUTEN FREE FLOUR (TAPIOCA FLOUR, BROWN RICE FLOUR, WHITE RICE FLOUR, SOY FLOUR, POTATO STARCH, XANTHAN GUM), SUGAR, WATER, ORGANIC PALM OIL, CHOCOLATE DIP (SUGAR, SOYBEAN OIL, COCOA, CHOCOLATE LIQUOR, SALT, VANILLA EXTRACT), VANILLA EXTRACT, CINNAMON, AGAVE SYRUP, CREAM OF TARTAR, BAKING SODA, SALT.',
#  'CERTIFIED GLUTEN FREE OATS, RAISINS (GLYCERIN, SUNFLOWER OIL OR CANOLA OIL), MAPLE SUGAR, BROWN SUGAR, FLAX MEAL , SALT .',
#  'GLUTEN FREE FLOUR (WHITE RICE FLOUR, BROWN RICE FLOUR, POTATO STARCH, TAPIOCA FLOUR, XANTHAN GUM), CHOCOLATE CREAM FILLING (ORGANIC PALM OIL, SUGAR, COCOA POWDER (PROCESSED WITH ALKALI), CHOCOLATE LIQUOR, SOY LECITHIN, SALT NATURAL VANILLA EXTRACT, CINNAMON), SUGAR, ORGANIC PALM OIL, WATER, EGG, CHOCOLATE DIP (SUGAR, SOYBEAN OIL, COCOA CHOCOLATE LIQUOR, SALT VANILLA EXTRACT), VANILLA, CREAM OF TARTAR, AGAVE SYRUP, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORNSTARCH, MONOCALCIUM PHOSPHATE), SALT, BAKING SODA.',
#  'GLUTEN FREE FLOUR (WHITE RICE FLOUR, BROWN RICE FLOUR, POTATO STARCH, TAPIOCA FLOUR, XANTHAN GUM), VANILLA CREAM (AGAVE, NATURAL VANILLA EXTRACT, SUGAR, ORGANIC PALM OIL, CORN SYRUP, WATER), SUGAR, ORGANIC PALM OIL, WATER, EGG, COCOA (PROCESSED WITH ALKALI), NATURAL VANILLA EXTRACT, CREAM OF TARTAR, AGAVE SYRUP, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORNSTARCH, MONOCALCIUM PHOSPHATE), SALT, BAKING SODA.',
#  'GLUTEN FREE FLOUR (WHITE RICE FLOUR, TAPIOCA FLOUR, POTATO STARCH, XANTHAN GUM), EGG, VANILLA DIP (SUGAR, VEGETABLE SHORTENING, EMULSIFIER, VANILLA), SUGAR, FRUCTOSE, PALM OIL, NATURAL FLAVOR, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORNSTARCH, MONOCALCIUM PHOSPHATE), SALT, AGAVE SYRUP.',
#  'BROWN RICE FLOUR, BUCKWHEAT FLOUR*, CRANBERRIES, GOJI BERRIES, DARK CHOCOLATE(SUGAR, CHOCOLATE LIQUOR, COCOA BUTTER), COCONUT SUGAR*, COCONUT OIL, COCONUT FLOUR*, CACAO, VANILLA, BAKING POWDER.',
#  'HEMP HEARTS*, WALNUTS*, DATES*, PUMPKIN SEEDS*, SUNFLOWER SEEDS*, PRUNES*, RAISINS*, COCONUT NECTAR*.',
#  'COCONUT FLAKES*, COCONUT FLOUR*, COCONUT NECTAR*, COCONUT OIL*, VANILLA BEANS*, SEA SALT.',
#  "SWEET ALI'S FLOUR MIX (BROWN RICE FLOUR, POTATO STARCH, TAPIOCA STARCH, SWEET RICE FLOUR, WHITE RICE FLOUR, XANTHAN GUM), SUGAR, FILTERED WATER, NON-GMO CANOLA OIL, BROWN SUGAR, COCOA POWDER, FLAXSEED, VANILLA, BAKING POWDER, SEA SALT.",
#  "SUGAR, SWEET ALI'S FLOUR MIX (BROWN RICE FLOUR, POTATO STARCH, WHITE RICE FLOUR, TAPIOCA STARCH, SWEET RICE FLOUR, XANTHAN GUM), BUTTER, EGGS, MILK, VANILLA, BAKING POWDER, SEA SALT.",
#  "SWEET ALI'S FLOUR MIX (BROWN RICE FLOUR, POTATO STARCH, WHITE RICE FLOUR, TAPIOCA STARCH, SWEET RICE FLOUR, XANTHAN GUM), ENJOY LIFE CHOCOLATE CHUNKS (EVAPORATED CANE JUICE, NATURAL CHOCOLATE LIQUOR (NON-ALCOHOLIC), NON-DAIRY COCA BUTTER), BROWN SUGAR, SPECTRUM PALM OIL, NATURAL APPLESAUCE (APPLES, WATER, ASCORBIC ACID), SUGAR, VANILLA, BAKING POWDER, BAKING SODA, SEA SALT.",
#  "SUGAR, SWEET ALI'S FLOUR MIX (BROWN RICE FLOUR, POTATO STARCH, WHITE RICE FLOUR, TAPIOCA STARCH, SWEET RICE FLOUR, XANTHAN GUM), BUTTER, EGGS, BLUEBERRIES, MILK, LEMON EXTRACT, BAKING POWDER, SEA SALT.",
#  'WHITE RICE FLOUR, TAPIOCA FLOUR, CORNSTARCH, WATER, EGGS, CANOLA OIL, NON-FAT DRY MILK POWDER, SUGAR, HONEY, POTATO FLOUR, XANTHAN GUM, AGAR AGAR POWDER, GLUTEN FREE EGG REPLACER, SALT, YEAST, APPLE CIDER VINEGAR, MONOSODIUM PHOSPHATE, CALCIUM PROPIONATE.',
#  "SUGAR, SWEET ALI'S FLOUR MIX (BROWN RICE FLOUR, POTATO STARCH, WHITE RICE FLOUR, TAPIOCA STARCH, SWEET RICE FLOUR), EGGS, CANOLA OIL, RICE MILK (FILTERED WATER, ORGANIC BROWN RICE (PARTIALLY MILLED), ORGANIC EXPELLER PRESSED SAFFLOWER OIL ,/OR SUNFLOWER OIL ,/OR CANOLA OIL, TRICALCIUM PHOSPHATE, SEA SALT, VITAMIN A PALMITATE, VITAMIN D2, VITAMIN B12), VANILLA, BAKING POWDER, SEA SALT, XANTHAN GUM. FROSTING: POWDERED SUGAR (POWDERED SUGAR, CORN STARCH), EARTH BALANCE (NATURAL OIL BLEND (PALM FRUIT, CANOLA, SOYBEAN, FLAX, , OLIVE OILS), WATER, SALT, CONTAINS LESS THAN 2% OF NATURAL FLAVOR, SOY PROTEIN, SOY LECITHIN, LACTIC ACID (NON-DAIRY), , NATURALLY EXTRACTED ANNATTO ( COLOR), SPECTRUM (PALM OIL), RICE MILK (FILTERED WATER, ORGANIC BROWN RICE (PARTIALLY MILLED), ORGANIC EXPELLER PRESSED SAFFLOWER OIL ,/OR SUNFLOWER OIL, TRICALCIUM PHOSPHATE, VITAMIN A PALMITATE, VITAMIN D2, VITAMIN B12, FOLIC ACID, COCOA POWDER, VANILLA.",
#  "SWEET ALI'S FLOUR MIX (BROWN RICE FLOUR, POTATO STARCH, TAPIOCA STARCH, SWEET RICE FLOUR, WHITE RICE FLOUR, XANTHAN GUM), SUGAR, FILTERED WATER, NON-GMO CANOLA OIL, BROWN SUGAR, COCOA POWDER, FLAXSEED, VANILLA, BAKING POWDER, SEA SALT.",
#  'BELLA GLUTEN-FREE ALL PURPOSE BAKING MIX (WHOLE GRAIN BROWN RICE FLOUR, WHITE RICE FLOUR, POTATO STARCH, SWEET RICE FLOUR, TAPIOCA STARCH, XANTHAN GUM, SEA SALT), ORGANIC CANE SUGAR, CHOCOLATE CHIPS (SUGAR, UNSWEETENED CHOCOLATE, COCOA BUTTER, <1% SOY LECITHIN, VANILLA BEAN SEEDS), ORGANIC COCONUT SUGAR, BAKING SODA.',
#  'WHOLE GRAIN BROWN RICE FLOUR,POTATO STARCH, WHOLE GRAIN SORGHUM FLOUR, TAPIOCA STARCH, XANTHAN GUM, ORGANIC CANE SUGAR, SEA SALT, YEAST PACKET.',
#  'BELLA GLUTEN-FREE ALL PURPOSE BAKING MIX (WHOLE GRAIN BROWN RICE FLOUR, WHITE RICE FLOUR, POTATO STARCH, SWEET RICE FLOUR, TAPIOCA STARCH, XANTHAN GUM, SEA SALT), ORGANIC COCONUT SUGAR, ORGANIC CANE SUGAR, CHOCOLATE CHIPS (SUGAR, UNSWEETENED CHOCOLATE, COCOA BUTTER, <1% SOY LECITHIN, VANILLA BEAN SEEDS), COCOA POWDER, BAKING SODA, ORGANIC GROUND VANILLA BEAN.',
#  "RICE FLOUR, SHARP CHEDDAR CHEESE (PASTEURIZED MILK, CHEESE CULTURES, ENZYMES, ANNATTO [VEGETABLE COLOR]), BUTTER (CREAM, SALT), PIZZA SPICE BLEND (GARLIC, MARJORAM, ONION, BASIL, OREGANO), POTATO STARCH, TAPIOCA STARCH, TOMATO POWDER, PARMESAN CHEESE (COW'S MILK, CHEESE CULTURES, SALT, ENZYMES), GUAR GUM, CREAM OF TARTAR, BAKING SODA , SEA SALT",
#  'WHOLE GRAIN BLEND (ORGANIC SORGHUM FLOUR, ORGANIC BROWN RICE FLOUR), ORGANIC POTATO STARCH, TAPIOCA STARCH, SWEET RICE FLOUR, ALUMINUM FREE BAKING POWDER (MONOCALCIUM PHOSPHATE, SODIUM BICARBONATE , CORN STARCH), XANTHAN GUM',
#  'WHOLE GRAIN BROWN RICE FLOUR, WHITE RICE FLOUR, POTATO STARCH, SWEET RICE FLOUR, TAPIOCA STARCH, XANTHAN GUM, BAKING SODA, CREAM OF TARTAR, SEA SALT.',
#  'TAPIOCA STARCH, WHOLE GRAIN BROWN RICE FLOUR, WHOLE GRAIN SORGHUM FLOUR, POTATO STARCH, FLAX SEED MEAL, SESAME SEEDS, ORGANIC CANE SUGAR, SUNFLOWER SEEDS, SEA SALT, XANTHAN GUM, YEAST PACKET.',
#  'BROWN RICE FLOUR, WHITE RICE FLOUR, POTATO STARCH, TAPIOCA FLOUR, BROWN SUGAR, NON-GMO CANOLA OIL, EGGS, POTATO FLOUR, YEAST, GARLIC POWDER, GUAR GUM, SALT, HERBS , SPICES',
#  'WATER, TAPIOCA FLOUR, SORGHUM FLOUR, SUNFLOWER OIL, EGGS, ARROWROOT STARCH, BROWN RICE FLOUR, WHITE RICE FLOUR, MAPLE SYRUP, GUAR GUM, SEA SALT, SEASONING, SPICES',
#  'WATER, BROWN RICE FLOUR, TAPIOCA STARCH, POTATO STARCH, EXPELLER PRESSED CANOLA OIL, MADE FROM NON-GENETICALLY MODIFIED SEED, PSYLLIUM POWDER, EGG WHITES, EVAPORATED CANE SUGAR, YEAST, TEFF FLOUR, FLAX SEED, SALT, CULTURED DEXTROSE, XANTHAN GUM, GUAR GUM, CITRIC ACID.',
#  'GLUTEN-FREE OATS, BROWN CANE SUGAR, GROUND FLAX, SEA SALT.',
#  'GLUTEN FREE FLOUR (TAPIOCA STARCH, WHITE RICE FLOUR, CORN STARCH), WATER, PALM OIL, SUGAR, EGGS, CHOCOLATE CHIPS (SUGAR, CHOCOLATE LIQUOR, COCOA BUTTER), CONFECTION SUGAR, COCOA, CANOLA OIL, BAKING POWDER, NATURAL VANILLA EXTRACT, SALT, XANTHAN GUM, AGAR, CALCIUM CARBONATE, CALCIUM SULFATE.',
#  'MILK CHOCOLATE (SUGAR, COCOA BUTTER, WHOLE MILK POWDER, COCOA MASS, SOY LECITHIN (EMULSIFIER)), NATURAL FLAVORING) BISCUIT (RICE FLOUR, MAIZE FLOUR, POTATO STARCH, XANTHAN GUM, SUGAR, BUTTER (MILK)), MARSHMALLOW (GLUCOSE SYRUP, SUGAR, WATER, MAIZE STARCH, BEEF GELATIN, NATURAL FLAVORINGS, NATURAL COLOR), COCONUT OIL, BUTTER OIL (MILK), PARTIALLY INVERTED SUGAR SYRUP, SUGAR, CARAMEL (SWEETENED CONDENSED SKIMMED MILK, GLUCOSE SYRUP (SULFITES), PARTIALLY INVERTED SUGAR SYRUP, VEGETABLE OIL (PALM), BUTTER (MILK), SUGAR, WATER, MONO , DI-GLYCERIDES (EMULSIFIER), STABILIZER (PECTIN (EMULSIFIER)), SALT, NATURAL FLAVORING), GLUCOSE SYRUP (SULFITES), SOY LECITHIN (EMULSIFIER), SALT.',
#  "WATER, PIZZA CHEESE (LOW MOISTURE MOZZARELLA CHEESE [PASTEURIZED MILK, CHEESE CULTURES, SALT, ENZYMES], UNSMOKED PROVOLONE CHEESE [PASTEURIZED MILK, CHEESE CULTURES, SALT, ENZYMES], GRATED PARMESAN CHEESE [PASTEURIZED PART SKIM MILK, CHEESE CULTURES, SALT, ENZYMES], GRATED ROMANO CHEESE [PASTEURIZED PART SKIN COW'S MILK, CHEESE CULTURES, SALT, ENZYMES], POWDERED CELLULOSE TO PREVENT CAKING, NATAMYCIN TO PROTECT FLAVOR), PIZZA SAUCE (TOMATO PUREE [WATER, TOMATO PASTE], EXTRA VIRGIN OLIVE OIL, SALT SPICES, GARLIC, CITRIC ACID), WHITE RICE FLOUR, BROWN RICE FLOUR, POTATO FLOUR, POTATO STARCH, OLIVE OIL, TAPIOCA STARCH, YEAST, SUGAR, GARLIC, XANTHAN GUM, SALT, BAKING POWDER (CORN STARCH, SODIUM BICARBONATE, SODIUM ALUMINUM SULFATE, MONOCALCIUM PHOSPHATE).",
#  'CAGE-FREE EGGS, ARROWROOT FLOUR, ORGANIC COCONUT MILK (ORGANIC COCONUT, 0.26% ORGANIC GUAR GUM), CAGE-FREE EGG WHITES, ORGANIC COCONUT OIL, UNFILTERED APPLE CIDER VINEGAR, ORGANIC COCONUT FLOUR, LEMON JUICE, ORGANIC PSYLLIUM HUSK POWDER, SEA SALT, RAW HONEY. TOPPINGS: MOZZARELLA CHEESE (PASTEURIZED PART-SKIM MILK, CHEESE CULTURES, SALT ENZYMES), TOMATO PUREE (TOMATOES, SALT, NATURALLY-DERIVED CITRIC ACID), ONION, EXTRA-VIRGIN OLIVE OIL, BASIL, GARLIC, SALT.',
#  'REFRIED BEANS (COOKED BEANS, WATER, CANOLA OIL, SALT), RICE (WATER, RICE), CHICKEN MEAT (CHICKEN MEAT, SALT), CHEDDAR CHEESE (PASTEURIZED MILK, CHEESE CULTURES, SALT, ENZYMES, ANNATTO (COLOR)), SALSA (TOMATO [PEELED TOMATO, TOMATO PUREE, SALT], TOMATO JUICE [WATER, TOMATO CONCENTRATE, SALT, VITAMIN C], ONION, BELL PEPPER, PEPPER, PARSLEY, GARLIC, CILANTRO, HERBS, APPLE CIDER VINEGAR, SPICES, SEA SALT), CORN, SOUR CREAM (GRADE A CULTURED CREAM), RED BELL PEPPER, GARLIC SALT (SALT, GARLIC, GARLIC OIL). TORTILLA: WATER, CORN MASA FLOUR (ORGANIC GROUND WHITE CORN MASA FLOUR, TRACE OF LIME), POTATO STARCH, RICE FLOUR, HIGH OLEIC SAFFLOWER OIL, CORN STARCH, XANTHAN GUM.',
#  'SEMISWEET CHOCOLATE CHIPS (SUGAR, CHOCOLATE, COCOA BUTTER, MILKFAT, SOY LECITHIN, NATURAL FLAVORS); BROWN SUAGR; RICE FLOUR; RGBH-FREE UNSALTED BUTTER (PASTEURIZED CREAM (MILK), NATURAL FLAVORING); CAGE FREE EGGS; NON GMO SOY FLOUR; SUGAR; VANILLA EXTRACT; SALT; BAKING SODA; ALUMINUM FREE BAKING POWDER (SODIUM ACID PHOSPHATE, SODIUM BICARBONATE, CORN STARCH, MONOCALCIUM PHOSPHATE)',
#  'RICE FLOUR; SUGAR; RGBH-FREE UNSALTED BUTTER (PASTEURIZED CREAM (MILK), NATURAL FLAVORING); CAGE FREE EGGS; NON GMO SOY FLOUR; CREAM OF TARTAR; BAKING SODA; GROUND CINNAMON; SALT',
#  "SWEET ALI'S FLOUR MIX (BROWN RICE FLOUR, POTATO STARCH, WHITE RICE FLOUR, TAPIOCA STARCH, SWEET RICE FLOUR, XANTHAN GUM), SUGAR, NATURAL APPLE SAUCE (APPLES, WATER, ASCORBIC ACID), BLUEBERRIES, BANANAS, GF OATMEAL, EGGS, (WHOLE LIQUID EGGS, NISIN PREPARATION), BROWN SUGAR, NON-GMO CANOLA OIL, SPECTRUM PALM OIL, BAKING POWDER, BAKING SODA, CINNAMON, SEA SALT.",
#  'SHARP CHEDDAR (PASTEURIZED MILK, CHEESE CULTURES, ENZYMES, ANNATTO [VEGETABLE COLOR]), WHITE RICE FLOUR, BUTTER (CREAM, SALT), POTATO STARCH, TAPIOCA STARCH, CULTURED BUTTERMILK, GUAR GUM, CREAM OF TARTAR, BAKING SODA, SEA SALT.',
#  'CREAM CHEESE (PASTEURIZED MILK , CREAM, CHEESE CULTURE, SALT, STABILIZERS [CAROB BEAN ,/OR XANTHAN ,/OR GUAR GUMS ]), SUGAR, EGG, RASPBERRY FILLING (RASPBERRIES, LIQUID SUGAR (NATURAL SUGAR, WATER), WATER, FOOD STARCH-MODIFIED, ARTIFICIAL COLOR [RED 40], ERYTHORBIC ACID), BUTTER, BROWN RICE FLOUR, COCOA, POTATO STARCH, TAPIOCA STARCH, VANILLA, SALT, XANTHAN GUM',
#  'PARMESAN CHEESE, BROWN RICE FLOUR, WHITE RICE FLOUR, BUTTER, POTATO STARCH, TAPIOCA FLOUR, BROWN SUGAR, NON-GMO CANOLA OIL, EGGS, POTATO FLOUR, MUSTARD, HONEY, YEAST, GUAR GUM, SALT, SPICES',
#  'WATER, BROWN RICE FLOUR, TAPIOCA STARCH, POTATO STARCH, EXPELLER PRESSED CANOLA OIL MADE FROM NON-GENETICALLY MODIFIED SEED, PSYLLIUM POWDER, EGG WHITES, EVAPORATED CANE SUGAR, YEAST, TEFF FLOUR, SEASONING (DEHYDRATED SUN-DRIED TOMATOES (SALT ADDED  COLOR RETENTION , AS A PRESERVATIVE), DEHYDRATED ONION , GARLIC, SPICES), FLAX SEED, SALT, CULTURED DEXTROSE, XANTHAN GUM, GUAR GUM, CITRIC ACID',
#  'WHITE RICE FLOUR, SUGAR, POTATO STARCH, SODIUM BICARBONATE, XANTHAN GUM, SALT, SODIUM ACID PYROPHOSPHATE, MONOCALCIUM PHOSPHATE.',
#  'SUGAR, CREAM CHEESE (PASTEURIZED MILK , CREAM, CHEESE CULTURE, SALT, STABILIZERS [CAROB BEAN ,/OR XANTHAN ,/OR GUAR GUMS]), BUTTER, MILK CHOCOLATE CHIPS (SUGAR, CHOCOLATE, NONFAT MILK, COCOA BUTTER, MILK FAT, SOY LECITHIN, VANILLIN - ARTIFICIAL FLAVOR), BROWN RICE FLOUR, EGG, ALKALIZED COCOA, POWDERED SUGAR (SUGAR, CORNSTARCH), POTATO STARCH, TAPIOCA STARCH, VANILLA, SALT, XANTHAN GUM',
#  'GLUTEN FREE FLOUR (POTATO FLOUR, RICE FLOUR) WATER, POTATO STARCH, QUINOA, TAPIOCA STARCH, CANOLA OIL, SUGAR, DRY YEAST, BAKING POWDER, GUAR GUM, SALT, CORN FLOUR.',
#  'GLUTEN FREE FLOUR (CORN, WHITE RICE, TAPIOCA), PALM OIL, SUGAR, EGGS, WATER, CANOLA OIL, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORN STARCH, MONOCALCIUM PHOSPHATE), XANTHAN GUM, SALT, PURE VANILLA EXTRACT, SUNFLOWER LECITHIN, CHOCOLATE GLAZE (CONFECTION SUGAR, WATER, SUGAR, COCOA, CANOLA OIL, AGAR, CALCIUM CARBONATE, CALCIUM SULFATE, PURE VANILLA EXTRACT, SALT).',
#  'WHOLE GRAIN RICE FLOUR, WHITE RICE FLOUR, INULIN, RICE BRAN EXTRACT, CALCIUM CARBONATE, NIACINAMIDE (VITAMIN B3), THIAMIN MONONITRATE (VITAMIN B1), RIBOFLAVIN (VITAMIN B2), FOLIC ACID, VITAMIN D3.',
#  'GLUTEN FREE FLOUR (WHITE RICE, TAPIOCA, CORN, ARROWROOT, POTATO, SOY), WATER, EGGS, BROWN SUGAR, HONEY, DRY YEAST, PALM OIL, APPLE CIDER VINEGAR, FLAXSEED MEAL, SALT, XANTHAN GUM.',
#  'WATER, TAPIOCA STARCH, RICE FLOUR, YEAST, CELLULOSE POWDER, PSYLLIUM HUSK, POTATO STARCH, ALBUMEN EGG WHITE POWDER, WHOLEGRAIN MAIZE FLOUR, HI-MAIZE STARCH, PARTIALLY INVERTED REFINERS SYRUP, THICKENERS (HYDROXYPROPYL METHYL CELLULOSE, SODIUM CARBOXYMETHLYCELLULOSE), MAIZE STARCH, RAPESEED OIL, LODIZED SALT, RICE STARCH, RICE BRAN EXTRACT, FERMENTED SUGAR, PRESERVATIVE (ACETIC ACID), NATURAL FLAVORS.',
#  'WATER, TAPIOCA FLOUR, RICE FLOUR, TAPIOCA STARCH, YEAST, CELLULOSE POWDER, PSYLLIUM HUSK, POTATO STARCH, ALBUMEN EGG WHITE POWDER, HI-MAIZE STARCH, WHOLEGRAIN MAIZE FLOUR, INVERT SUGARS, THICKENERS (HYDROXYPROPYL METHYL CELLULOSE, SODIUM CARBOXYMETHLYCELLULOSE, XANTHUM GUM, CALCIUM SULPHATE), MAIZE STARCH, LINSEED, PLUM PUREE, SUGAR BEET PULP, RICE STARCH, RAPESEED OIL, GOLDEN MILLET SEED, POPPY SEED, SUNFLOWER SEED, IODIZED SALT, QUINOA SEED, RICE BRAN EXTRACT, CULTURE STARTER, FERMENTED SUGAR, PRESERVATIVE (ACETIC ACID), NATURAL FLAVORS.',
#  'GLUTEN-FREE BREAD: WATER, BROWN RICE FLOUR, TAPIOCA STARCH, POTATO STARCH, CANOLA OIL, PSYLLIUM POWDER, EGG WHITES, EVAPORATED CANE SUGAR, TEFF FLOUR, SEA SLAT, FLAX SEED, YEAST, XANTHAN GUM, GUAR GUM.   EGGS (EGG WHITES, MODIFIED FOOD STARCH (CORN), NONFAT DRY MILK, WHEY PROTEIN ISOLATE, SOYBEAN OIL, CARRAGEENAN, SALT, EGG FLAVOR, GUAR GUM, XANTHAN GUM, ANNATTO (COLOR)), ALFREDO SAUCE, (CREAM CHEESE (PASTEURIZED CULTURED MILK , CREAM, SALT, STABILIZER (XANTHAN GUM , OR CAROB BEAN , OR GUAR GUMS)), UNCURED BACON, (PORK, (NO NITRATES OR NITRITES ADDED EXCEPT THOSE NATURALLY OCCURING IN SEA SALT), NATURAL FLAVORINGS , CELERY POWDER)), WATER, SEA SALT, CANE SUGAR, NATURAL SMOKE FLAVORING, NATURAL FLAVORINGS, LACTIC ACID, STARTER CULTURE (NATURAL FERMENTING AGENT)), CHEDDAR CHEESE (PASTEURIZED MILK, CHEESE CULTURES, SALT, ENZYMES, ANNATTO (COLOR)), POWDERED CELLULOSE, CORN STARCH.',
#  'GLUTEN-FREE FLOUR TORTILLA (WHITE CORN MASA FLOUR , A TRACE OF LIME, WATER, PREGELATINIZED RICE FLOUR, POTATO FLOUR, HIGH OLEIC SAFFLOWER OIL, CORN STARCH, XANTHAN GUM , CULTURED DEXTROSE), REFRIED BEANS (BEANS, WATER, CANOLA OIL, SALT), RICE, SALSA (TOMATOES, TOMATO JUICE, (WATER, TOMATO CONCENTRATE, SALT, VITAMIN C), ONIONS, BELL PEPPERS, PEPPERS, PARSLEY, GARLIC, CILANTRO, APPLE CIDER VINEGAR, SPICES, SEA SALT, HERBS), COOKED CHICKEN, CHEDDAR CHEESE (PASTEURIZED MILK, CHEESE CULTURES, SALT, ENZYMES, ANNATTO COLOR), GMO FREE CORN, SOUR CREAM (GRADE A CULTURED CREAM (MILK), ENZYME), RED BELL PEPPER, GARLIC SALT (GARLIC, SALT, GARLIC OIL).',
#  'GLUTEN FREE ALL PURPOSE MIX (RICE-FLOUR, CORN STARCH, TAPIOCA DEXTRIN, XANTHAN GUM, RICE EXTRACT), SOUR CREAM (CULTURED MILK, CREAM, WHEY, FOOD STARCH-MODIFIED [CORN], SODIUM PHOSPHATE, GUAR GUM, CARRAGEENAN, CALCIUM SULFATE, LOCUST BEAN GUM, POTASSIUM SORBATE), SUGAR, BUTTER (CREAM, NATURAL FLAVORING), PASTEURIZED EGGS (PASTEURIZED LIQUID EGG [WHOLE EGG, CITRIC ACID, 0. 1% WATER ADDED AS A CARRIER  CITRIC ACID], ,/OR PASTEURIZED FRESH WHOLE EGG), BROWN SUGAR (SUGAR, MOLASSES), CINNAMON, RAISIN, VANILLA BEAN (SUGAR, WATER, VANILLA EXTRACT, VANILLA BEANS, GUM TRAGACANTH), BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORN STARCH, MONO PHOSPHATE), SALT, SODIUM BICARBONATE.',
#  'GLUTEN FREE FLOUR (WHITE RICE FLOUR, POTATO STARCH, XANTHAN GUM), CHOCOLATE CREAM (ORGANIC PALM OIL, SUGAR, COCOA POWDER (PROCESSED WITH ALKALI), CHOCOLATE LIQUOR, SOY LECITHIN, SALT, NATURAL VANILLA EXTRACT, CINNAMON), SUGAR, PALM OIL, EGG, NATURAL VANILLA, AGAVE SYRUP, CREAM OF TARTAR, BAKING SODA, SALT, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORNSTARCH, MONOCALCIUM PHOSPHATE).',
#  'GLUTEN FREE FLOUR (TAPIOCA FLOUR, BROWN RICE FLOUR, WHITE RICE FLOUR, SOY FLOUR, POTATO STARCH, XANTHAN GUM), SUGAR, WATER, ORGANIC PALM OIL, CINNAMON, AGAVE SYRUP, CREAM OF TARTAR, BAKING SODA, SALT.',
#  'GLUTEN FREE FLOUR (WHITE RICE FLOUR, BROWN RICE FLOUR, POTATO STARCH, TAPIOCA FLOUR, XANTHAN GUM), CHOCOLATE CREAM FILLING (ORGANIC PALM OIL, SUGAR, COCOA POWDER (PROCESSED WITH ALKALI), CHOCOLATE LIQUOR, SOY LECITHIN, SALT, NATURAL VANILLA EXTRACT, CINNAMON), SUGAR, ORGANIC PALM OIL, WATER, EGG, CHOCOLATE DIP (SUGAR, SOYBEAN OIL, COCOA, CHOCOLATE LIQUOR, SALT, VANILLA EXTRACT), VANILLA, CREAM OF TARTAR, AGAVE SYRUP, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORNSTARCH, MONOCALCIUM PHOSPHATE), SALT, BAKING SODA.',
#  'GLUTEN FREE FLOUR (BROWN RICE FLOUR, POTATO STARCH, TAPIOCA FLOUR, XANTHAN GUM), PALM OIL, CHOCOLATE CHIPS (SUGAR, COCOA POWDER (PROCESSED WITH ALKALI), CHOCOLATE LIQUOR, SOY LECITHIN, SOY LECITHIN, VANILLA EXTRACT), SUGAR, BROWN SUGAR, EGG, VANILLA, BAKING SODA, AGAVE SYRUP, CREAM OF TARTER, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORNSTARCH,MONOCALCIUM PHOSPHATE), SALT.',
#  'CHOCOLATE CHIPS (UNSWEETENED CHOCOLATE, SUGAR, DEXTROSE, SOY LECITHIN, NATURAL VANILLA EXTRACT), BROWN RICE FLOUR, BUTTER, SUGAR, BROWN SUGAR, EGG, POTATO STARCH, TAPIOCA STARCH, BAKING SODA, SALT, VANILLA, XANTHAN GUM',
#  'BROWN RICE FLOUR, CORN STARCH, FLOUR MIX (RICE FIBER, PEA PROTEIN, FLAXSEED MEAL, SORGHUM FLOUR, BUCKWHEAT FLOUR, MILLET FLOUR), SUGAR, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORN STARCH, MONOCALCIUM PHOSPHATE MONOHYDRATE, CALCIUM SULFATE), SODIUM BICARBONATE, SALT, XANTHAN GUM.',
#  'SUGAR, BROWN RICE FLOUR, BUTTER, EGG, POTATO STARCH, TAPIOCA STARCH, CREAM OF TARTAR, BAKING SODA, SALT, XANTHAN GUM, VANILLA',
#  'CAKE MIX (SUGAR, RICE FLOUR, COCOA PROCESSED WITH ALKALI, NATURAL , ARTIFICIAL FLAVOR, MODIFIED RICE STARCH, EGG WHITES, LEAVENING [SODIUM BICARBONATE, SODIUM ACID PYROPHOSPHATE, MONOCALCIUM PHOSPHATE, CORN STARCH] CONTAINS 2% OR LESS OF: MODIFIED CORN STARCH, SOLUABLE CORN FIBER, SALT, POLYGLYCEROL ESTERS, POTATO STARCH, XANTHAN GUM, MONO , DIGLYCERIDES). POWDERED SUGAR (SUGAR, CORNSTARCH), WATER, SOY SHORTENING (PARTIALLY HYDROGENATED SOYBEAN , PALM OILS WITH POLYGLYCEROL ESTERS OF FATTY ACIDS ADDED), CANOLA OIL, EGGS, VANILLIN (WATER, VANILLIN, ETHYL VANILLIN, NATURAL FLAVOR, ARTIFICIAL FLAVOR, PROPYLENE GLYCOL), BLUE FOOD COLOR (WATER, SUGAR, US CERTIFIED COLORS FD&C RED #3 & BLUE #1, MODIFIED CORN STARCH, VEGETABLE GUM, CITRIC ACID, LESS THAN .1 OF 1% SODIUM BENZOATE & POTASSIUM SORBATE AS PRESERVATIVES), RED FOOD COLOR (WATER, SUGAR, FD&C COLORS [RED #40, RED #3, YELLOW #6], MODIFIED CORN STARCH, VEGETABLE GUM, CITRIC ACID, LESS THAN 1/10 OF 1% SODIUM BENZOATE , POTASSIUM SORBATE), SALT',
#  'GLUTEN FREE FLOUR (WHITE RICE, TAPIOCA, CORN), PALM OIL, SUGAR, WATER, EGGS, COCOA, CANOLA OIL, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORN STARCH, MONOCALCIUM PHOSPHATE), XANTHAN GUM, SALT, PURE VANILLA EXTRACT, SUNFLOWER LECITHIN, VANILLA GLAZE (CONFECTION SUGAR, WATER, SUGAR, CANOLA OIL, AGAR, CALCIUM CARBONATE, CALCIUM SULFATE, PURE VANILLA EXTRACT, SALT).',
# ...
#  'GLUTEN FREE FLOUR (POTATO, TAPIOCA, SORGHUM, WHITE RICE, BROWN RICE, CORN), CANOLA OIL, EGGS, SUGAR, WATER, ORANGE JUICE, CINNAMON, PURE VANILLA EXTRACT, PURE VANILLA POWDER, CONFECTIONERS SUGAR, DRY YEAST, XANTHAN GUM, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, POTATO STARCH, MONOCALCIUM PHOSPHATE), SALT.',
#  'WATER, GLUTEN FREE FLOUR (BROWN RICE FLOUR, WHITE RICE FLOUR, MODIFIED TAPIOCA STARCH, TAPIOCA STARCH, POTATO STARCH, SOY FLOUR, SORGHUM FLOUR, POTATO FLOUR, CORN FLOUR), RAISINS, CINNAMON, SUGAR, XANTHAN GUM, SALT, DRY YEAST, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORN STARCH, MONOCALCIUM PHOSPHATE).',
#  'GLUTEN FREE FLOUR (WHITE RICE, TAPIOCA, CORN), PALM OIL, SUGAR, WATER, EGGS, COCOA, CANOLA OIL, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM ACID BICARBONATE, MONOCALCIUM PHOSPHATE, CORN STARCH), XANTHAN GUM, SALT, SUNFLOWER LECITHIN, PURE VANILLA EXTRACT. VANILLA GLAZE: (CONFECTIONERS SUGAR, WATER, SUGAR, CANOLA OIL, AGAR, CALCIUM CARBONATE, CALCIUM SULFATE, PURE VANILLA EXTRACT, SALT).',
#  'PIZZA CRUST (GLUTEN FREE FLOUR (NON-GMO CORNSTARCH, NON-GMO POTATO STARCH, NON-GMO SORGHUM FLOUR, NON-GMO RICE FLOUR, NON-GMO POTATO FLOUR] NON-GMO CORN OIL, CANE SUGAR, YEAST, SALT, XANTHAN GUM, OLIVE OIL), PIZZA SAUCE (TOMATOES IN JUICE [TOMATOES, TOMATO JUICE, SALT, , CALCIUM CHLORIDE), PIZZA SAUCE (TOMATO PUREE, TOMATOES, CANOLA OIL, SALT, EXTRA VIRGIN OLIVE OIL, PECORINO ROMANO CHEESE, SPICES , GARLIC]), MOZZARELLA CHEESE (CULTURED PASTEURIZED WHOLE MILK, SALT, , ENZYMES), PARMESAN (PASTEURIZED PART-SKIM MILK, CHEESE CULTURES, SALT, ENZYMES), SPICE.',
#  'WATER, RICE FLOUR, SUGAR, CORN STARCH, TAPIOCA STARCH, CANOLA OIL, YEAST, HYDROXYPROPYL METHYL CELLULOSE, CELLULOSE GUM, METHYL CELLULOSE, XANTHAN GUM, GUAR GUM, WHOLE GRAIN CORN FLOUR, EGG WHITE POWDER, PSYLLIUM HUSK POWDER, POTATO STARCH, GLYCERIN, NATURAL FLAVORS, IODIZED SALT (SALT, POTASSIUM IODATE), WHOLE LIQUID EGG, SUGAR CANE FIBER, SODIUM PROPIONATE (PRESERVATIVE), SORBIC ACID (PRESERVATIVE), RICE STARCH, CONCENTRATED GRAPE JUICE, RICE BRAN, SPIRIT VINEGAR, BETA CAROTENE (COLOR), SODIUM CARBONATE (ACIDITY REGULATOR).',
#  'ALMOND FLOUR, CAGE-FREE EGGS, TAPIOCA FLOUR, XANTHAN GUM, SEA SALT',
#  'ORGANIC POTATO, ALMOND FLOUR, CAGE-FREE EGG WHITES, SWEET POTATO FLOUR, SWEET POTATO JUICE, TAPIOCA FLOUR, CAGE-FREE EGGS, POTATO STARCH, SEA SALT, ANNATO SEED',
#  'ORGANIC POTATO, ALMOND FLOUR, CAGE-FREE EGGS, TAPIOCA FLOUR, SEA SALT',
#  'CAGE-FREE+ EGGS, ALMOND FLOUR, ARROWROOT FLOUR, CASSAVA FLOUR, COCONUT MILK, COCONUT OIL, EXTRA VIRGIN OLIVE OIL, PSYLLIUM HUSK, LEMON JUICE, SEA SALT, UNFILTERED APPLE CIDER VINEGAR, HONEY. TOPPINGS: PIZZA SAUCE (TOMATO PUREE, SALT, GARLIC, OLIVE OIL, SPICES, CITRIC ACID), WHOLE MILK MOZZARELLA (PASTEURIZED MILK, CHEESE CULTURES, SALT, ENZYMES), UNCURED PEPPERONI++ (PORK, BEEF, SALT, CONTAINS 2% OR LESS OF WATER, SPICE, SEASONING (CANE SUGAR, CELERY JUICE POWDER), SEASONING (PAPRIKA EXTRACT, NATURAL SPICE EXTRACT), LACTIC ACID STARTER CULTURE), WHITE CHEDDAR (PASTEURIZED MILK, CHEESE CULTURES, SALT, ENZYMES)',
#  'CAGE-FREE+ EGGS, ALMOND FLOUR, ARROWROOT FLOUR, CASSAVA FLOUR, COCONUT MILK, COCONUT OIL, EXTRA VIRGIN OLIVE OIL, PSYLLIUM HUSK, LEMON JUICE, SEA SALT, UNFILTERED APPLE CIDER VINEGAR, HONEY',
#  'CAGE-FREEâ€\xa0 EGGS, ALMOND FLOUR, ARROWROOT FLOUR, CASSAVA FLOUR, COCONUT MILK, COCONUT OIL, EXTRA VIRGIN OLIVE OIL, PSYLLIUM HUSK, LEMON JUICE, SEA SALT, UNFILTERED APPLE CIDER VINEGAR, HONEY; TOPPINGS: PIZZA SAUCE (TOMATO PUREE, SALT, GARLIC, OLIVE OIL, SPICES, CITRIC ACID), WHOLE MILK MOZZARELLA (PASTEURIZED MILK, CHEESE CULTURES, SALT, ENZYMES), ITALIAN SAUSAGEâ€¡ (PORK, SPICES, SALT, SUGAR, NATURAL FLAVORINGS, DEHYDRATED GARLIC), ROASTED RED BELL PEPPERS, WHITE CHEDDAR (PASTEURIZED MILK, CHEESE CULTURES, SALT, ENZYMES)',
#  'GLUTEN FREE FLOUR (WHITE RICE FLOUR, BROWN RICE FLOUR, POTATO STARCH, TAPIOCA FLOUR, XANTHAN GUM), DUTCH PROCESSED COCOA POWDER, RASPBERRY JAM (RASPBERRIES, SUGAR, FRUIT PECTIN, CITRIC ACID), SUGAR, PALM OIL, VANILLA CREAM (SUGAR, PALM OIL, NATURAL VANILLA FLAVOR, SUNFLOWER LECITHIN, SALT), TIRAMISU NATURAL & ARTIFICIAL FLAVOR (WATER, PROPYLENE GLYCOL, CARMEL COLOR, XANTHAM GUM), EGG, POWDERED SUGAR (SUGAR, CORNSTARCH), CHOCOLATE DIP (SUGAR, SOYBEAN OIL, COCOA, CHOCOLATE LIQUOR, SALT, VANILLA EXTRACT), WATER, VANILLA, AGAVE SYRUP, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORNSTARCH, MONOCALCIUM PHOSPHATE), CREAM OF TARTAR, SALT, BAKING SODA.',
#  'GOLD POTATOES, WATER, GARBANZO BEAN FLOUR, SWEET WHITE RICE FLOUR, TAPIOCA FLOUR, NON GMO/RBD CANOLA OIL, GMO VEGETABLE OIL SPREAD ((PALM FRUIT, CANOLA, , OLIVE OILS), WATER, SALT, CONTAINS LESS THAN 2% OF NATURAL FLAVOR, SUNFLOWER LECITHIN, LACTIC ACID, ANNATTO EXTRACT), XANTHAN GUM, SALT, DILL WEED, GUAR GUM.',
#  'GLUTEN FREE FLOUR (CORN, WHITE RICE, TAPIOCA), PALM OIL, SUGAR, EGGS, WATER, CANOLA OIL, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORN STARCH, MONOCALCIUM PHOSPHATE), XANTHAN GUM, SALT, PURE VANILLA EXTRACT, SUNFLOWER LECITHIN, VANILLA GLAZE (CONFECTION SUGAR, WATER, SUGAR, CANOLA OIL, AGAR, CALCIUM CARBONATE, CALCIUM SULFATE, PURE VANILLA EXTRACT, SALT).',
#  'GLUTEN FREE FLOUR (WHITE RICE FLOUR, BROWN RICE FLOUR, POTATO STARCH, TAPIOCA FLOUR, XANTHAN GUM), DUTCH PROCESSED COCOA POWDER, RASPBERRY JAM (RASPBERRIES, SUGAR, FRUIT PECTIN, CITRIC ACID), SUGAR, PALM OIL, VANILLA CREAM (SUGAR, PALM OIL, NATURAL VANILLA FLAVOR, SUNFLOWER LECITHIN, SALT), TIRAMISU NATURAL & ARTIFICIAL FLAVOR (WATER, PROPYLENE GLYCOL, CARMEL COLOR, XANTHAM GUM), EGG, POWDERED SUGAR (SUGAR, CORNSTARCH), CHOCOLATE DIP (SUGAR, SOYBEAN OIL, COCOA, CHOCOLATE LIQUOR, SALT, VANILLA EXTRACT), WATER, VANILLA, AGAVE SYRUP, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORNSTARCH, MONOCALCIUM PHOSPHATE), CREAM OF TARTAR, SALT, BAKING SODA.',
#  'WATER, WHITE RICE FLOUR, TAPIOCA FLOUR, EGG WHITES, NON-GMO SUNFLOWER OIL, ORGANIC SOY MILK POWDER, SUGAR, XANTHAN GUM, LEAVENING (SODIUM BICARBONATE), KOSHER SALT, YEAST, WHITE DISTILLED VINEGAR, GELATIN. TOPPINGS: EARTH BALANCE BUTTERY SPREAD (VEGETABLE OIL BLEND (PALM FRUIT, CANOLA, SAFFLOWER, FLAX, , OLIVE OILS), WATER, CONTAINS LESS THAN 2% OF SALT, NATURAL FLAVOR, PEA PROTEIN, SUNFLOWER LECITHIN, LACTIC ACID (TO PROTECT FRESHNESS), , ANNATTO EXTRACT (COLOR)), ROMA TOMATO, BASIL, GARLIC POWDER, ITALIAN SEASONINGS, KOSHER SALT.',
#  'GLUTEN FREE FLOUR (TAPIOCA STARCH, WHITE RICE FLOUR, STEAMED CHICKPEA FLOUR, CORN STARCH, FLAXSEED MEAL), WATER, EGGS, PALM OIL, CANOLA OIL, SUGAR, HONEY, BROWN SUGAR, XANTHAN GUM, SALT, DRY YEAST, CINNAMON, APPLE CIDER VINEGAR, NATURAL FLAVOR, NUTMEG.',
#  'WATER, WHITE RICE FLOUR, TAPIOCA FLOUR, EGG WHITES, NON-GMO SUNFLOWER OIL, ORGANIC SOY MILK POWDER, SUGAR, XANTHAN GUM, LEAVENING (SODIUM BICARBONATE), KOSHER SALT, YEAST, WHITE DISTILLED VINEGAR, GELATIN. SAUCE: VINE-RIPENED FRESH TOMATOES, SALT, NATURALLY DERIVED CITRIC ACID, ITALIAN SEASONING, GARLIC POWDER, ONION POWDER, PAPRIKA, BLACK PEPPER, TOPPINGS: MOZZARELLA CHEESE (PASTEURIZED MILK, CHEESE CULTURE, SALT, ENZYMES).',
#  'SULFITE FREE COCONUT, PURE CANE SUGAR, EGG WHITES, SALT, PURE VANILLA EXTRACT, CREAM OF TARTAR',
#  'ALMOND FLOUR, ORGANIC MAPLE SYRUP, CHOCOLATE MORSELS (UNSWEETENED CHOCOLATE, ORGANIC CANE SUGAR, COCOA BUTTER), ARROWROOT FLOUR, ORGANIC UNREFINED COCONUT OIL, ORGANIC VANILLA EXTRACT, SEA SALT, BAKING SODA.',
#  'SULFITE FREE COCONUT, INVERT SUGAR, TAPIOCA, COCOA, EGG WHITE.',
#  'BELLA GLUTEN-FREE ALL PURPOSE BAKING MIX (WHOLE GRAIN BROWN RICE FLOUR, WHITE RICE FLOUR, POTATO STARCH, SWEET RICE FLOUR, TAPIOCA STARCH, XANTHAN GUM, SEA SALT), ORGANIC CANE SUGAR, CHOCOLATE CHIPS (SUGAR, UNSWEETENED CHOCOLATE, COCOA BUTTER, <1% SOY LECITHIN, VANILLA BEAN SEEDS), ORGANIC COCONUT SUGAR, BAKING SODA.',
#  'WHOLE GRAIN BROWN RICE FLOUR, WHITE RICE FLOUR, POTATO STARCH, SWEET RICE FLOUR, TAPIOCA STARCH, XANTHAN GUM, BAKING SODA, CREAM OF TARTAR, SEA SALT.',
#  'GLUTEN-FREE FLOUR (SORGHUM FLOUR, WHITE RICE FLOUR, NON-GMO CORNSTARCH, TAPIOCA STARCH, MILLET FLOUR), SUGAR, PSYLLIUM HUSK POWDER, YEAST, SALT, XANTHAN GUM, ASCORBIC ACID (VITAMIN C)',
#  'ALMOND FLOUR, ORGANIC VERMONT MAPLE SYRUP, DARK CHOCOLATE MORSELS (UNSWEETENED CHOCOLATE, ORGANIC CANE SUGAR, COCOA BUTTER), ORGANIC COCONUT OIL, ARROWROOT FLOUR, ORGANIC COCOA POWDER, ORGANIC VANILLA EXTRACT, BAKING SODA, COARSE SEA SALT.',
#  'GLUTEN FREE FLOUR (CORN, WHITE RICE, TAPIOCA), PALM OIL, SUGAR, EGGS, WATER, CANOLA OIL, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORN STARCH, MONOCALCIUM PHOSPHATE), XANTHAN GUM, SALT, PURE VANILLA EXTRACT, SUNFLOWER LECITHIN, VANILLA GLAZE (CONFECTION SUGAR, WATER, SUGAR, CANOLA OIL, AGAR, CALCIUM CARBONATE, CALCIUM SULFATE, PURE VANILLA EXTRACT, SALT).',
#  'EGGS, SUGAR, GLUTEN FREE FLOUR (BROWN RICE, WHITE RICE, CORN, POTATO STARCH, TAPIOCA, POTATO FLOUR), WATER, CONFECTIONERS SUGAR, PALM OIL, CANOLA OIL, PURE VANILLA EXTRACT, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORN STARCH, MONOCALCIUM PHOSPHATE), XANTHAN GUM, SALT.',
#  "VANILLA  (GLUTEN FREE FLOUR [WHITE RICE FLOUR, POTATO STARCH, TAPIOCA STARCH, XANTHAN GUM], PALM OIL, SUGAR, EGG, VANILLA, BAKING POWDER [SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORNSTARCH, MONOCALCIUM PHOSPHATE], AGAVE SYRUP, CREAM OF TARTAR, BAKING SODA, SALT), SPRINKLES (SUGAR, GLUCOSE POWDER, TAPIOCA STARCH, STARCH, PALM KERNEL FAT, VEGETABLE OIL, SALT, CORN STARCH, GLYCERIN, MAGNESIUM SILICATE, SOY LECITHIN, TALC, GUM ARABIC, FD&C COLORS: BLUE #1, ARTIFICIAL FLAVOR, CONFECTIONER'S GLAZE, , CARNAUBA WAX)",
#  'GLUTEN FREE FLOUR (WHITE RICE FLOUR, BROWN RICE FLOUR, POTATO STARCH, TAPIOCA FLOUR, XANTHAN GUM), DUTCH PROCESSED COCOA POWDER, RASPBERRY JAM (RASPBERRIES, SUGAR, FRUIT PECTIN, CITRIC ACID), SUGAR, PALM OIL, VANILLA CREAM (SUGAR, PALM OIL, NATURAL VANILLA FLAVOR, SUNFLOWER LECITHIN, SALT), TIRAMISU NATURAL & ARTIFICIAL FLAVOR (WATER, PROPYLENE GLYCOL, CARMEL COLOR, XANTHAM GUM), EGG, POWDERED SUGAR (SUGAR, CORNSTARCH), CHOCOLATE DIP (SUGAR, SOYBEAN OIL, COCOA, CHOCOLATE LIQUOR, SALT, VANILLA EXTRACT), WATER, VANILLA, AGAVE SYRUP, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORNSTARCH, MONOCALCIUM PHOSPHATE), CREAM OF TARTAR, SALT, BAKING SODA.',
#  'GOLD POTATOES, WATER, GARBANZO BEAN FLOUR, SWEET WHITE RICE FLOUR, TAPIOCA FLOUR, NON GMO/RBD CANOLA OIL, GMO VEGETABLE OIL SPREAD ((PALM FRUIT, CANOLA, , OLIVE OILS), WATER, SALT, CONTAINS LESS THAN 2% OF NATURAL FLAVOR, SUNFLOWER LECITHIN, LACTIC ACID, ANNATTO EXTRACT), XANTHAN GUM, SALT, DILL WEED, GUAR GUM.',
#  'WATER, WHITE RICE FLOUR, TAPIOCA FLOUR, EGG WHITES, NON-GMO SUNFLOWER OIL, ORGANIC SOY MILK POWDER, SUGAR, XANTHAN GUM, LEAVENING (SODIUM BICARBONATE), KOSHER SALT, YEAST, WHITE DISTILLED VINEGAR, GELATIN. TOPPINGS: EARTH BALANCE BUTTERY SPREAD (VEGETABLE OIL BLEND (PALM FRUIT, CANOLA, SAFFLOWER, FLAX, , OLIVE OILS), WATER, CONTAINS LESS THAN 2% OF SALT, NATURAL FLAVOR, PEA PROTEIN, SUNFLOWER LECITHIN, LACTIC ACID (TO PROTECT FRESHNESS), , ANNATTO EXTRACT (COLOR)), ROMA TOMATO, BASIL, GARLIC POWDER, ITALIAN SEASONINGS, KOSHER SALT.',
#  'GLUTEN FREE FLOUR (TAPIOCA STARCH, WHITE RICE FLOUR, STEAMED CHICKPEA FLOUR, CORN STARCH, FLAXSEED MEAL), WATER, EGGS, PALM OIL, CANOLA OIL, SUGAR, HONEY, BROWN SUGAR, XANTHAN GUM, SALT, DRY YEAST, CINNAMON, APPLE CIDER VINEGAR, NATURAL FLAVOR, NUTMEG.',
#  'WATER, WHITE RICE FLOUR, TAPIOCA FLOUR, EGG WHITES, NON-GMO SUNFLOWER OIL, ORGANIC SOY MILK POWDER, SUGAR, XANTHAN GUM, LEAVENING (SODIUM BICARBONATE), KOSHER SALT, YEAST, WHITE DISTILLED VINEGAR, GELATIN. SAUCE: VINE-RIPENED FRESH TOMATOES, SALT, NATURALLY DERIVED CITRIC ACID, ITALIAN SEASONING, GARLIC POWDER, ONION POWDER, PAPRIKA, BLACK PEPPER, TOPPINGS: MOZZARELLA CHEESE (PASTEURIZED MILK, CHEESE CULTURE, SALT, ENZYMES).',
#  'GLUTEN FREE FLOUR (TAPIOCA STARCH, WHITE RICE FLOUR, STEAMED CHICKPEA FLOUR, CORN STARCH, FLAXSEED MEAL), WATER, EGGS, PALM OIL, CANOLA OIL, SUGAR, HONEY, BROWN SUGAR, XANTHAN GUM, SALT, DRY YEAST, APPLE CIDER VINEGAR, CINNAMON, NATURAL FLAVOR, NUTMEG.',
#  'GLUTEN FREE FLOUR (TAPIOCA STARCH, BROWN RICE FLOUR), EGGS, CHOCOLATE CHIPS (SUGAR, UNSWEETENED CHOCOLATE, COCOA BUTTER), SUGAR, BROWN SUGAR, CANOLA OIL, WATER, BAKING POWDER, SUNFLOWER LECITHIN, NATURAL FLAVORS, XANTHAN GUM, SALT.',
#  'SUGAR. GLUTEN FREE FLOUR (WHITE RICE FLOUR, TAPIOCA STARCH), EGGS, CANOLA OIL, WATER, COCOA, PURE VANILLA EXTRACT, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, POTATO, STARCH, MONOCALCIUM PHOSPHATE), XANTHAN GUM, CHOCOLATE FROSTING (SUGAR, PALM OIL, A BLEND OF COCOA POWDERS (PROCESSED WITH ALKALI). CHOCOLATE LIQUOR. SOY LECITHIN, SALT), COLORED SPRINKLES (SUGAR, CORN STARCH, TURMERIC & BOTANICAL EXTRACTS  COLOR, CARNAUBA WAX).',
#  'FARMER CHEESE (CULTURED PASTEURIZED GRADE A 2% MILK), WATER, GARBANZO BEAN FLOUR, EGG, SWEET WHITE RICE FLOUR, TAPIOCA FLOUR, GREEN ONION, NON GMO/RBD CANOLA OIL, XANTHAN GUM, SALT, GUAR GUM.',
#  'ALL PURPOSE GF FLOUR (BROWN RICE FLOUR, POTATO FLOUR, TAPIOCA FLOUR, POTATO STARCH, WHITE RICE FLOUR, XANTHAN GUM), ORGANIC CANE SUGAR, VEGAN BUTTERY SPREAD [(OIL BLEND (PALM FRUIT, CANOLA, OLIVE), WATER, SALT, NATURAL FLAVOR, SUNFLOWER LECITHIN, LACTIC ACID, ANNATTO EXTRACT], ORGANIC BROWN SUGAR, VEGAN CHOCOLATE (ORGANIC SUGAR, CHOCOLATE, COCOA BUTTER, SOY LECITHIN, VANILLA BEAN), WATER, TAPIOCA SYRUP, LESS THAN 2% OF: PALM FRUIT OIL, PURE VANILLA EXTRACT (WATER, ALCOHOL 40%, VANILLA BEANS), CREAM OF TARTAR, SUNFLOWER LECITHIN, KOSHER SALT, BAKING SODA, GUAR GUM, KONJAC, XANTHAN GUM',
#  'ALL PURPOSE GF FLOUR (BROWN RICE FLOUR, POTATO FLOUR, TAPIOCA FLOUR, POTATO STARCH, WHITE RICE FLOUR, XANTHAN GUM), ORGANIC CANE SUGAR, GLUTEN FREE OATS, VEGAN BUTTERY SPREAD [(OIL BLEND (PALM FRUIT, CANOLA, OLIVE), WATER, SALT, NATURAL FLAVOR, SUNFLOWER LECITHIN, LACTIC ACID, ANNATTO EXTRACT], ORGANIC BROWN SUGAR, WATER, TAPIOCA SYRUP, PALM FRUIT OIL, BAKING SODA, PURE VANILLA EXTRACT (WATER, VANILLA BEAN, ALCOHOL 40%), SUNFLOWER LECITHIN, CREAM OF TARTAR, SPICE, KOSHER SALT, KONJAC, GUAR GUM, XANTHAN GUM',
#  'GLUTEN FREE FLOUR (TAPIOCA STARCH, BROWN RICE FLOUR), EGGS, SUGAR, CANOLA OIL, BROWN SUGAR, WATER, BLUEBERRIES, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, POTATO STARCH, MONOCALCIUM PHOSPHATE), LECITHIN, NATURAL FLAVOR, XANTHAN GUM, SALT, SUNFLOWER OIL.',
#  'EGGS, SUGAR, GLUTEN FREE FLOUR (BROWN RICE FLOUR, WHITE RICE FLOUR, CORN STARCH, TAPIOCA STARCH, POTATO STARCH, POTATO FLOUR), CONFECTIONERS SUGAR (SUGAR, CORN STARCH), WATER, PALM OIL, CANOLA OIL, PUMPKIN, SPICES, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORN STARCH, MONOCALCIUM PHOSPHATE), PURE VANILLA EXTRACT, XANTHAN GUM, SALT.',
#  'GLUTEN FREE FLOUR (WHITE RICE FLOUR, BROWN RICE FLOUR, TAPIOCA STARCH, POTATO STARCH, POTATO FLOUR), SUGAR, BROWN SUGAR, EGGS, CANOLA OIL, WATER, PALM OIL, HONEY, COCOA, NATURAL FLAVORS, XANTHAN GUM, SALT.',
#  'EGGS, SUGAR, GLUTEN FREE FLOUR (BROWN RICE FLOUR, WHITE RICE FLOUR, CORN STARCH, TAPIOCA STARCH, POTATO STARCH, POTATO FLOUR), WATER, CONFECTIONERS SUGAR (SUGAR, CORN STARCH), PALM OIL, CANOLA OIL, COCOA, WATER, NATURALLY COLORED SPRINKLES (SUGAR, CORN STARCH, VEGETABLE EXTRACT, CARNUBA WAX), BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM BICARBONATE, CORN STARCH, MONOCALCIUM PHOSPHATE), XANTHAN GUM, NATURAL PEPPERMINT FLAVOR, ALL-NATURAL GREEN COLOR (PLANT EXTRACTIVES (CONTAINS SUNFLOWER LECITHIN)), SALT.',
#  'GLUTEN FREE FLOUR (WHITE RICE FLOUR, TAPIOCA STARCH, CORN STARCH), SUGAR, PALM OIL, WATER, EGGS, CANOLA OIL, BAKING POWDER (SODIUM ACID PYROPHOSPHATE, SODIUM ACID BICARBONATE, MONOCALCIUM PHOSPHATE, CORN STARCH), NUTMEG, CINNAMON, SUNFLOWER LECITHIN, GINGER, SALT, CLOVES, XANTHAN GUM, AGAR, CALCIUM CARBONATE, CALCIUM SULFATE, NATURAL FLAVOR.',
#  'GLUTEN FREE FLOUR (TAPIOCA, WHITE RICE, SORGHUM, CORN), PALM OIL, WATER, EGGS, SUGAR, SALT, XANTHAN GUM. BLUEBERRY  BLUEBERRIES, WATER, SUGAR, CORN SYRUP MODIFIED FOOD STARCH, VEGETABLE GUM, CITRIC ACID, VEGETABLE EXTRACT.',
#  ...]

# %% [markdown]
# Removing white space

# %% [markdown]
# -----

# %%
# finding out how many indredients are in the file
len(clean_data_stripped)

# %% [markdown]
# #### Count unique values in a list

# %%
Counter(clean_data_stripped)

# %% [markdown]
# Adding the data back into the dataset

# %% [markdown]
# -----

# %%
gf_df = pd.DataFrame(clean_data_stripped, columns=['ingredients'])
gf_df.head(6)

# %% [markdown]
# Process of removing duplicates

# %%
gf_df.shape

# %%
gf_df.duplicated().sum()

# %%
# Check in terms of percentages
gf_df.duplicated().sum()/gf_df.shape[0]*100

# %%
clean_data = gf_df.drop_duplicates()

# %%
clean_data.shape

# %%
clean_data.value_counts()

# %%
clean_data_stripped = [item.strip() for item in clean_data]

# %%
clean_data_stripped

# %% [markdown]
# -------
#
# -----

# %% [markdown]
# # Adding New Dataset

# %% [markdown]
# This shows us that the target column is not balanced - far more customers are not registered for the product opposed to those who did (60/40 split). We will convert this column to a binary one, where 1 represents registering and 0 represents not registering.

# %%
df['registered'] = np.where(df['registered'] == 'yes', 1, 0)

# %%
#Sanity Check
df.head()

# %%
#Sanity Check 2

df['registered'].value_counts()

# %% [markdown]
# Now we've converted the target. Let's ensure it's the correct datatype and look at which other columns need changing.

# %%
df.info()

# %% [markdown]
# Next, let's look at categorical columns with fewer distinct values as they will be quicker to preprocess. Let's start with the `marital` column:

# %%
#check 
df['marital']

# %% [markdown]
# Let's check the unique or distinct values in more detail.

# %%
df['marital'].value_counts()

# %% [markdown]
# If we just had `married` or `divorced`, we could have converted this into a binary. However we have the `single` option as well, and this is a large chunk of the data as well. Much like `jobs` which we can tackle later.

# %%
df.head()

# %% [markdown]
# Looking at the above, it appears that `credit_in_default`, `housing_loan` and `personal_loan` are binary in nature. Let's examine these and see if we can convert them such that that can be read in a model.

# %%
#Check
df['credit_in_default'].value_counts()

# %% [markdown]
# Looking at the above, there are a lot of customers with unknown credit status but only 1 with 'yes'. Some of the unknown are likely in default. We make the argument that these are different things from a data standpoint (in terms of what the bank knows about the customer). Therefore , we will consider credit not in defualt to be zero, otherwise (unknnonw and yes) as 1.

# %%
# Here because there are multiple values we will use a map function

df['credit_in_default'].map({'no': 0, 'yes': 1, 'unknown': 1})

# %%
df['credit_in_default'] = df['credit_in_default'].map({'no': 0, 'yes': 1, 'unknown': 1})

# %%
#Check
df['credit_in_default'].value_counts()

# %% [markdown]
# We have binarized credit in defualt. Let's change the name of the column based on our assumption that there is a higher likelihood of unknowns being actual credit_in_default than not.

# %%
#Rename our column
df.rename(columns={'credit_in_default':'known_credit_in_default'}, inplace=True)

# %%
df.head()

# %% [markdown]
# What else is left.

# %%
df.info()

# %% [markdown]
# Hopefully Housing and Personal Loans will require a similar approach. Let's take a look:

# %%
df['housing_loan'].value_counts()

# %%
df['personal_loan'].value_counts()

# %% [markdown]
# It looks like 260 people have unknown in each column. In this case we can check if it's the same people.

# %%
df[(df['housing_loan'] == 'unknown') & (df['personal_loan'] == 'unknown')]

# %% [markdown]
# Seems like it's the same people who might have left that column blank. Let's plot the distributions as well.

# %%
plt.subplots(1,2, figsize=(8, 6))

plt.subplot(1,2,1)
df['personal_loan'].value_counts().plot(kind='barh')
plt.title("Personal Loans")
plt.xlabel("Counts")


plt.subplot(1,2,2)
df['housing_loan'].value_counts().plot(kind='barh')
plt.title("Housing Loans")
plt.xlabel("Counts")

plt.tight_layout()

plt.show()

# %% [markdown]
# Looking at these we can give it the same treatment as credit_in_default. Therefore we will lump the unknowns to `no`. and rename the column.

# %%
#Personal Loan
df['known_personal_loan'] = df['personal_loan'].map({'no': 0, 'unknown': 0, 'yes': 1})

# %%
#Sanity Check
df['known_personal_loan'].value_counts()

# %% [markdown]
# Let's do the same thing with housing_loans.

# %%
#Personal Loan
df['known_housing_loan'] = df['housing_loan'].map({'no': 0, 'unknown': 0, 'yes': 1})

# %%
#Sanity Check
df['known_housing_loan'].value_counts()

# %% [markdown]
# Let's drop the original columns for these 2.

# %%
df.drop(columns=['housing_loan', 'personal_loan'], inplace=True)

# %% [markdown]
# Sanity check plus what else is left.

# %%
df.info()

# %% [markdown]
# Let's look at last_contact_type.

# %%
df['last_contact_type'].value_counts()

# %% [markdown]
# Lucky for us, this is 2 distinct types. Let's encode it as `last_contact_type_cellular`

# %%
df['last_contact_type_cellular'] = np.where(df['last_contact_type'] == 'cellular', 1, 0)

# %%
#Check
df['last_contact_type_cellular'].value_counts()

# %% [markdown]
# We will drop last_contact_type

# %%
df.drop(columns='last_contact_type', inplace=True)

# %%
df.info()

# %%
for col in ['location', 'prev_campaign_outcome', 'last_contact_day', 'last_contact_month', 'education', 'marital', 'job']:
    print(col.upper()) #Upper() makes it uppercase
    print(df[col].value_counts())
    print('\n')
    print("-------------------------------")

# %% [markdown]
# ---

# %% [markdown]
# As seen above, we need to deal with columns that have multiple options. Let's start with Education. We can group all basic education as 1 and illiterate and unknown.

# %%
df['education'] = df['education'].map({'university.degree': 'university.degree',
                                      'unknown': 'unknown',
                                      'high.school': 'high.school',
                                      'professional.course': 'professional.course',
                                      'illiterate': 'unknown',
                                      'basic.6y': 'basic',
                                      'basic.4y': 'basic',
                                      'basic.9y': 'basic'})

# %%
#Sanity Check
df['education'].value_counts()

# %% [markdown]
# Let's also look at the date and day columns in the data to see if they have any trends. Potentially customers may be more likely to sign up on one day compared to another (similar to months). We can also see seasonality patterns (this is a hypothesis). We will encode this with increasing integers for our model.

# %%
#last_contact_day
df['last_contact_day'].value_counts()

# %% [markdown]
# We see there are no contacts on the weekend. If we had them we could have done a binary of week vs weekend.

# %%
df['last_contact_day'] = df['last_contact_day'].map({'mon': 1, 'tue':2, 'wed': 3, 'thu': 4, 'fri': 5})

# %%
df['last_contact_day'].value_counts()

# %%
df['last_contact_day'].value_counts().sort_index().plot(kind='bar')
plt.title("Count of Customers being contacted by weekday")
plt.xlabel("Weekday #")
plt.ylabel("Count of contacts")
plt.show()

# %% [markdown]
# Interesting to note, appears to be more contacts on Thursday, and less on Fridays than on other days of the week.

# %%
# Last contact month
df['last_contact_month'].value_counts()

# %%
# Try pd.to_datetime instead of using map...
df['last_contact_quarter'] = pd.to_datetime(df['last_contact_month'], format='%b').dt.quarter

# %% [markdown]
# For the months, we encode it based on the results of the previous analysis as 'good months' (Sep, Oct, Dec, Mar, Apr) and 'bad months' (everything else). The good months show a higher percent of people signing up.

# %%
# alernative - code as good month bad month as 

good_months = ['apr', 'oct', 'mar', 'sep', 'dec']

df['good_month'] = 0

df.loc[df['last_contact_month'].isin(good_months), 'good_month'] = 1

# %%
df['good_month'].value_counts()

# %% [markdown]
# Now we have rolled up the last contact month to the quarter and encoded these as integers. We choose to drop last contact month after this, although this a choice we are making - we could have a greater level of detail by encoding last contact month as 1,2,3,...12 if we had so chosen.

# %%
df['last_contact_quarter'].value_counts().sort_index().plot(kind='bar')
plt.show(df['last_contact_quarter'].value_counts().sort_index().plot(kind='bar'))
plt.show()

# %%
# Drop last_contact_month
df.drop('last_contact_month', axis=1, inplace=True)

# %% [markdown]
# Interesting to note above, very little contact in the data in Q1, most of the customers in the campaign were previously contacted in Q2, and then this drops steeply off up until Q4.
#
# What's left?

# %%
df.info()

# %% [markdown]
# #### Dummy Variables
#
# To numerically represent catregorical variables with many nominal distinct values we can use ***dummy variables***. A dummy variable is a binary variable that takes values of 0 and 1, where the values indicate the presence or absence of something. A categorical variable that has more than two categories can be represented by a set of dummy variables, with one variable being used to indicate the presense/absence for each category.
#
# Dummy variables are also known as ***One-hot encoding*** since only one of the dummy variables for each category can have a value of 1 at a time.

# %%
states = pd.Series(['NY','Boston','Texas','NY'])
states

# %%
pd.get_dummies(states)

# %%
df.head()

# %%
# Stating dummy variables for our categorical columns

df['job'].value_counts()

# %%
df['marital'].value_counts()

# %%
pd.get_dummies(df['marital'])

# %% [markdown]
# When you have a categorical column with a lot of classes, the first thing to do is to group them and make sure that dummy variables wouldn't lead to many columns (20-30). For this example, we will drop the location column but other options would be to group the locations based on the city names and reduce the number of dummy variables.

# %%
df.drop('location', axis=1, inplace=True)

# %%
df.head()

# %%
df.select_dtypes('object')

# %%
# Dataframe with dummy variables
dummy_df = pd.get_dummies(df)

# %%
# To see all of the columns
pd.set_option('display.max_columns',200)

# %%
dummy_df.head()

# %%
# Decision about dropping column

pd.get_dummies(df['marital']).var()

# %%
pd.get_dummies(df['job']).var().sort_values(ascending=False)

# %%
pd.get_dummies(df['job']).sum().sort_values(ascending=False)

# %%
pd.get_dummies(df['prev_campaign_outcome']).sum().sort_values(ascending=False)

# %%
# Columns to drop to avoid multicollinearity from our dummy variables
refrence_Categories = ['marital_unknown', 'job_unknown', 'education_unknown', 'prev_campaign_outcome_nonexistent']

# %%
dummy_df.drop(columns=refrence_Categories, inplace=True)

# %%
dummy_df.info()

# %%
dummy_df.sample(10)

# %% [markdown]
# ### Part 2: Modeling
#
# Now that we are satisfied our data is ready to be put into a model, we proceed to the model building phase of our analysis. First, we need to ensure that certain assumption hold about the data: these include our samples being independent and identically distributed, and that the independent variables are not collinear or show multicollinearity.

# %%
# Pull out features and target for modeling

X = dummy_df.drop('registered', axis=1)
y= dummy_df['registered']

# %% [markdown]
# #### Collinearity & Multicollinearity
#
# **Applies to:**
#
#    - Linear & Logistic regression models
#
# **What is it?**
#
# - **Collinearity** refers to the situation when two independent variables are correlated with one another.
# - **Multicollinearity** is the situation where one independent variable can be expressed as a linear combination of two or more other independent variables (in other words, the independent variables are in a linear relationship with *each other*).
#
# **What does it do to our models?**
#
#  - We often see certain independent variables be given much lower coefficients than what the correlation between that variable and the dependent variable would suggest. It may also go against our prior subject matter knowledge.
#
#  - The coefficient standard errors may also be very high, suggesting that the model is unsure about its prediction.
#
#  - As a result of both of the above, p-values are likely to be highly skewed, and may lead us to make incorrect conclusions about the significance of the variable.
#
# **Why does this happen?**
#
# Fundamentally, linear regression models use how an independent variable varies with a dependent variable to estimate the coefficient value that describes the change in the $y$. This is why correlation between the independent variable and dependent variables is important to have. If there is a strong relationship the model can look at the data and say "Ah, if $x$ increases by 1, then $y$ generally increases by ~2"
#
# In multiple linear regression, where we have multiple independent variables, we also need to factor in how the independent variables vary with *each other* as well as the dependent variable. Consider this extreme scenario:
#
#    - Two independent variables $x_1$ and $x_2$ have very strong correlation with each other, |$\rho|\geq 0.9 $
#    - Both variables variables share strong positive correlation with the dependent $y$, $\rho \approx 0.7 $
#
# In the scenario above, the model will be unsure about which independent variable is the one that actually driving the relationship with the dependent variable. Ultimately both independent variables seem to move in the same way.
#
# The result of this confusion is that the model will assign the majority of the relationship to one of the variables, and assign little to the other. As a result, one coefficient value will be high and the other very low! This may not match up with what we would expect and lead us to make conclusions about the relationship between the independent variables and the dependent variable that do not reflect the true relationship.
#
# #### Detecting Collinearity
#
# Collinearity can be detected by finding the pairwise **correlation** between the independent variables (we typically visualize this as a heatmap). If a linear/logistic regression model is to be fitted, this should always be part of the exploratory phase. If the correlation between some predictors is high, it is a sign of collinearity and we can consider including only one of those predictors in our models (or to combine the information in those predictors some way).
#
# Let us explore collinearity in our dataset.

# %%
X.head()

# %%
# Calculated the correlation matrix

corr_df = X.corr()


mask = np.triu(corr_df)
plt.figure(figsize=(20,20))
sns.heatmap(corr_df.round(2), annot=True,mask=mask, vmin=-1, vmax=1, cmap='coolwarm')
plt.show()

# %%
X[['prev_campaign_outcome_success','n_contacts_prev_campaign']].describe()

# %%
X.drop('n_contacts_prev_campaign',axis=1 ,inplace=True)

# %%
# Calculated the correlation matrix

corr_df = X.corr()


mask = np.triu(corr_df)
plt.figure(figsize=(20,20))
sns.heatmap(corr_df.round(2), annot=True,mask=mask, vmin=-1, vmax=1, cmap='coolwarm')
plt.show()

# %%
X[['marital_married','marital_single']].describe()

# %%
X.drop('marital_single',axis=1 ,inplace=True)

# %%
# Calculated the correlation matrix

corr_df = X.corr()


mask = np.triu(corr_df)
plt.figure(figsize=(20,20))
sns.heatmap(corr_df.round(2), annot=True,mask=mask, vmin=-1, vmax=1, cmap='coolwarm')
plt.show()

# %% [markdown]
# #### Detecting Multicollinearity with the Variance Inflation Factors
#
# Looking at correlations only won't detect multicollinearity, hence we need a new tool: the **Variance Inflation Factor** (VIF).
#
# In order to calculate it, we build a regression model of each independent variable against the other independent variables and look at the $R^2$ score. The VIF for each predictor is defined as
# $$
# \text{VIF}_i = \frac{1}{1-R_i^2}
# $$
#
# In a perfect scenario of no multicollinearity, the VIF for each predictor should be 1 (since the $R^2$ from each model would be 0, showing that the given independent variable can't be modeled by the other variables, hence no linear relationship).
#
# By common convention, any VIF value higher than 5 indicates high multicollinearity. Let's examine the VIF for the variables in our dataset:

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
X_withcons = sm.add_constant(X)

# %%
X.head()

# %%
variance_inflation_factor(X_withcons.values, 1)

# %%
pd.Series([variance_inflation_factor(X_withcons.values, i) for i in range(X_withcons.shape[1])],
         index = X_withcons.columns)[1:]

# %% [markdown]
# A VIF score of above 5 (R2 >=0.8) indicates multi colliniearity. So in this case we don't need to be worried about that.

# %% [markdown]
# #### Variable Selection
#
# You will hopefully find that some combinations of variables will give almost the same performance using fewer predictors and hence, less multicollinearity.
#
#
# Even if there isn't any collinearity or multicollinearity present, it's common to try and find a simpler model that will have almost the same performance as a more complicated model. This is usually done by adding or removing variables until all are significant (p-value < 0.05).
#
# The technical term for this is called variable selection. In fact there's a few way to do this, some of which are:
#
# - **Forward Selection**: Starting with the intercept only, at each step, select the candidate variable that increases R-Squared the most.
#
# - **Backward Selection**: Starting with a full model (all predictors), at each step, the variable that is the least significant is removed. In the case of multicollinearity, the variable removed may be the one with the highest VIF scores.
#
# - **Stepwise Selection**: Combination of the above two, after each step in which a predictor was added, all predictor candidates in the model are checked to see if their significance has been reduced below a p-value of 0.05.

# %% [markdown]
# #### Forward Feature Selection
#
# The following diagram demonstrates the forward selection approach:
#
# <img src="https://drive.google.com/uc?export=view&id=19RfhvLdwjnlps_Kx4qMZWrpJQab_E2Hi" alt="Backward Selection" width="600" height="700"/>

# %% [markdown]
# #### Backward Feature Selection
#
# The backward selection approach can be imagined as this:
#
# <img src="https://drive.google.com/uc?export=view&id=1HbSW65W_tZR6N5wCFDTtsabYwDSAT3QP" alt="Backward Selection" width="600" height="700"/>

# %% [markdown]
# ### Backward Selection
# In backward selection, we fit a model with all data available to us to start, then remove variables based upon whether or not they are significant (and informed by subject matter knowledge), until will reach a model of desired simplicity with sufficient predictive power.
#
# Let's start the feature selection process with our data set now:

# %%
import statsmodels.api as sm

# %%
# 0: Add the constant

X_cons = sm.add_constant(X)

#1: Instantiate the model

bank_logit = sm.Logit(y, X_cons)

#2: Fit the model

bank_logit_fitted = bank_logit.fit()

# %%
bank_logit_fitted.summary()

# %% [markdown]
# We note above, that for many variables, the associated p-values with the coefficients (the betas) are large. Therefore, we cannot safely reject the null hypothesis ($\beta_i = 0$), so in pratical terms, these independent variables are likely not predictive of the dependent variable. We try excluding these from the model and seeing if this has an effect or not. Note that removing many variables at once is to be avoided, as the p-values will vary based upon which are left in or out of the model together in combination.
#
# Regardless of this fact, we can still make a prediction for y. We will do this leaving in the insignificant variables to establish a baseline accuracy:
#
# ### Part 4: Model Evaluation & Summary
#
# We've made some models, now let's try to interpret them and summarize our findings.

# %%
# Making soft prediction
y_prob = bank_logit_fitted.predict(X_cons)

y_prob

# %%
y_pred = np.where(y_prob>=0.5, 1, 0)

y_pred

# %% [markdown]
# Let's now calculate the model accuracy by comparing the predictions with the actual values

# %%
correct_predictions = (y_pred == y).sum()

total_obs = X_cons.shape[0]

# The model accuracy

print(f'The model accuracy is {round(correct_predictions/total_obs,2)}')

# %% [markdown]
# ## Iteration 2
#
# Dropping columns with high p values to see how it affects the model performance.

# %%
# 0: Add the constant

X2_cons = sm.add_constant(X)

#1: Instantiate the model

bank_logit2 = sm.Logit(y, X2_cons)

#2: Fit the model

bank_logit_fitted2 = bank_logit2.fit()

# %%
bank_logit_fitted2.summary()

# %%
# Making soft prediction
y_prob2 = bank_logit_fitted2.predict(X2_cons)

y_prob2

# %%
# Hard prediction
y_pred2 = np.where(y_prob2>=0.5, 1, 0)

y_pred2

# %%
correct_predictions2 = (y_pred2 == y).sum()

total_obs = X2_cons.shape[0]

# The model accuracy

print(f'The model accuracy is {round(correct_predictions2/total_obs,2)}')

# %% [markdown]
# ## Model interpretation

# %%
bank_logit_fitted2.params

# %%
plt.figure(figsize=(10,10))
bank_logit_fitted2.params.sort_values(ascending=True).plot(kind='barh')
plt.show()

# %% [markdown]
# Looking at the figure above `prev_campaign_outcome_success` as is the month of contact and type of that contact. In terms of demographics, students or retired folks are more likely to sign up.
#
# Factors that are negatively predictive, that is to say, mean a customer is less likely to accept to product are having their credit in default, and a blue collar or services role, to name a few.

# %%
highest_param = bank_logit_fitted2.params.sort_values(ascending=False)['prev_campaign_outcome_success']

# %% [markdown]
# To quantify further, we could look at the log odds. For example, for the student variable:

# %%
np.exp(highest_param)

# %% [markdown]
# Having a `prev_campaign_outcome_success` can increase the odds of someone getting the loan increases by 15.
#
# To take this a step even further, we could calculate the log odds for variables of interest and plot this information. This would give us and our stakeholders a handy reference when discussing variable importance.

# %%
coefficient_df = pd.DataFrame({'coef': bank_logit_fitted2.params, 
                              'pvals': bank_logit_fitted2.pvalues})

# %%
coefficient_df

# %%
coefficient_df.reset_index(inplace=True)
coefficient_df.rename({'index':'variable'}, axis=1, inplace=True)

# %%
coefficient_df.head()

# %% [markdown]
# In the above cell, we can filter out the variables with pvals less than 5% and then use them to run a model and compare its performance with the previous one that we built.

# %%
coefficient_df[coefficient_df['pvals']<0.05]['variable']

# %% [markdown]
# Let's build a bar chart based on this data. We will convert coefficients into odds increases and decreases, color them in red and blue based on increase or decrease, and change the saturation based on p-values.

# %%
categories = []    # Holds labels for bars
sizes = []         # Hold bar heights
colors = []        # Holds bar colors
p_values = []      # Used for additional text within the plot

p_value_color_scale = 1.5

# iterate through
for index, row in coefficient_df.iterrows():
    variable_name = row['variable'].strip()
    
    if (variable_name != 'const'):   # We don't care much for the constant since we can modify it
        
        
        categories.append(variable_name)
        coefficient_value = row['coef']
        
        p_value = round(row['pvals'],2)
        p_values.append(p_value)
        


        color = [1.0,1.0,1.0]
        
        color[1] = (min(p_value_color_scale*p_value, 1.0)/1.0)  # Make GREEN brighter
        
        if (coefficient_value >= 0):
            color[0] = color[1]                     # Make RED brighter
            column_size = np.exp(coefficient_value)
        else:
            color[2] = color[1]                     # Make BLUE brighter
            column_size = -1/np.exp(coefficient_value)

        column_size = round(column_size,2)
        sizes.append(column_size)
        colors.append(color)

# %% [markdown]
# Let's create a bar chart with some text labels as well. If the p-value is larger than, or equal to, 0.05, we will label that bar

# %%
fix, ax = plt.subplots(figsize=(16, 12))
ax.barh(categories, sizes, color=colors)
for index, bar_size in enumerate(sizes):
    if (bar_size > 0.0):
        # Add a label text
        ax.text(bar_size + 0.5, index-0.15, f'{bar_size} odds increase', color='blue')
        
        # Add a p-value disclaimer
        if (p_values[index] >= 0.05):
            ax.text(-2.5, index-0.15, f'p-value={p_values[index]}', color='blue')
    else:
        # Label text
        ax.text(bar_size - 3.7, index-0.15, f'{abs(bar_size)} odds decrease', color='red')
        
        # p-value disclaimer
        if (p_values[index] >= 0.05):
            ax.text(0.3, index - 0.15, f'p-value={p_values[index]}', color='red')

# change the limit to make sure labels go inside the plot area
plt.xlim(-7.5, 16.5)
plt.title("Effect of Different Variables on Odds Increase (blue) or Decrease (red).\
\nColors are Less Intense for Statistically Insignificant Items", size=20)
plt.xlabel("Odds change for a given feature", size=20)
plt.ylabel("Variable of interest", size=20)
plt.show()

# %% [markdown]
# #### Forward Selection vs. Backward
#
# In forward selection, we will instead start with a single variable we think is most predictive (start with the simplest model) and then add variables instead of removing them as in backward selection above.

# %%
# Look at correlation between each variable and the target
dummy_df.corr()['registered'].sort_values(ascending=False)

# %% [markdown]
# `last_contact_duration` appears to have the highest correlation with the target (`registered`), so we will start with it as our first variable to build our initial model:

# %%
# Instantiate the model with a SINGLE variable - we will choose last_contact_duration given the above
new_X = X['last_contact_duration']
new_X_const = sm.add_constant(new_X)

# Instantiate
forward_logit = sm.Logit(y, new_X_const)

# Fit
fitted_forward = forward_logit.fit()

# Summary
fitted_forward.summary()

# %% [markdown]
# We can see in the above that the p-value is very small, so we can safely reject the null hypothesis that $\beta_1=0$ and say there is evidence to support it being predictive of the target outcome.

# %%
# Calculate soft predictions
y_proba = fitted_forward.predict(new_X_const)

# Convert soft predictions to hard predictions 0/1
y_pred = np.where(y_proba >= 0.5, 1, 0)

# Calculate # correct
num_correct = (y_pred == y).sum()

# Calculate the percentage accuracy
pct_accuracy = num_correct / X.shape[0]

print(f'The baseline model accuracy is {pct_accuracy*100.0}%')

# %% [markdown]
# We were able to predict the target with 71% accuracy, using only a single variable! This is very close to our baseline performance in backward selection. The reality may be more complicated. We could do further analysis and continue to add variables and see the effect on model performance until reaching an optimal model with the best trade-off between predictive power and model complexity.

# %% [markdown]
# ---
#
# **Note:** continue adding features to this simple model and track how the coefficients and model performance changes.
#
# ---

# %% [markdown]
# <div id="container" style="position:relative;">
# <div style="position:relative; float:right"><img style="height:25px""width: 50px" src ="https://drive.google.com/uc?export=view&id=14VoXUJftgptWtdNhtNYVm6cjVmEWpki1" />
# </div>
# </div>
