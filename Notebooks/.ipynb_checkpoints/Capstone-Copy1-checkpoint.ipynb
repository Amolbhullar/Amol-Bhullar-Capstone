# %% [markdown]
# <div id="container" style="position:relative;">
# <div style="float:left"><h1> Data Preprocessing and Modeling</h1></div>
# </div>

# %% [markdown]
# ### Importing the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import re

# %% [markdown]
# # Uploading Dataset 1

# %%
#df = pd.read_csv('Gluten-freeDF.csv')

try:
    df = pd.read_csv('Gluten-freeDF.csv', encoding='utf-8')
except UnicodeDecodeError:
    try:
        df = pd.read_csv('Gluten-freeDF.csv', encoding='latin1')
    except UnicodeDecodeError:
        df = pd.read_csv('Gluten-freeDF.csv', encoding='ISO-8859-1')

# %%
# Check
df.head()
# Out:
#                         Ingredient  Gluten?
# 0                          2% Milk        0
# 1  Abies balsamea (Balsam fir) oil        0
# 2                             Abiu        0
# 3                       Acacia Gum        0
# 4                       Açaí Berry        0

# %% [markdown]
# -----

# %% [markdown]
# # Uploading Dataset 2

# %%
df2 = pd.read_csv('Gluten-free1.csv',encoding='utf-8')

# %%
df2.head()
# Out:
#                                          ingredients gluten-free?
# 0  ALL PURPOSE GF FLOUR (BROWN RICE FLOUR, POTATO...          yes
# 1  ALL PURPOSE GF FLOUR (BROWN RICE FLOUR, POTATO...          yes
# 2  GLUTEN FREE FLOUR (TAPIOCA STARCH, BROWN RICE ...          yes
# 3  GLUTEN FREE FLOUR (TAPIOCA, WHITE RICE, SORGHU...          yes
# 4  GLUTEN FREE FLOUR (TAPIOCA STARCH, WHITE RICE ...          yes

# %%
ing_row = df2["ingredients"]
ing_row.head()
# Out:
# 0    ALL PURPOSE GF FLOUR (BROWN RICE FLOUR, POTATO...
# 1    ALL PURPOSE GF FLOUR (BROWN RICE FLOUR, POTATO...
# 2    GLUTEN FREE FLOUR (TAPIOCA STARCH, BROWN RICE ...
# 3    GLUTEN FREE FLOUR (TAPIOCA, WHITE RICE, SORGHU...
# 4    GLUTEN FREE FLOUR (TAPIOCA STARCH, WHITE RICE ...
# Name: ingredients, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Ingredient  2253 non-null   object
#  1   Gluten?     2253 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 35.3+ KB

# %% [markdown]
# ------

# %% [markdown]
# ### Cleaning the Data

# %%
pattern = r'[(),\[\]:]'

individual_ingredients = []
for row in ing_row:
    ingredients_list = re.split(pattern, row)
    individual_ingredients.extend(ingredients_list)

# %% [markdown]
# Removing white space

# %%
clean_data_stripped = [item.strip() for item in individual_ingredients]

# %%
clean_data_stripped
# Out:
# ['ALL PURPOSE GF FLOUR',
#  'BROWN RICE FLOUR',
#  'POTATO FLOUR',
#  'TAPIOCA FLOUR',
#  'POTATO STARCH',
#  'WHITE RICE FLOUR',
#  'XANTHAN GUM',
#  '',
#  'ORGANIC CANE SUGAR',
#  'VEGAN BUTTERY SPREAD',
#  '',
#  'OIL BLEND',
#  'PALM FRUIT',
#  'CANOLA',
#  'OLIVE',
#  '',
#  'WATER',
#  'SALT',
#  'NATURAL FLAVOR',
#  'SUNFLOWER LECITHIN',
#  'LACTIC ACID',
#  'ANNATTO EXTRACT',
#  '',
#  'ORGANIC BROWN SUGAR',
#  'VEGAN CHOCOLATE',
#  'ORGANIC SUGAR',
#  'CHOCOLATE',
#  'COCOA BUTTER',
#  'SOY LECITHIN',
#  'VANILLA BEAN',
#  '',
#  'WATER',
#  'TAPIOCA SYRUP',
#  'LESS THAN 2% OF',
#  'PALM FRUIT OIL',
#  'PURE VANILLA EXTRACT',
#  'WATER',
#  'ALCOHOL 40%',
#  'VANILLA BEANS',
#  '',
#  'CREAM OF TARTAR',
#  'SUNFLOWER LECITHIN',
#  'KOSHER SALT',
#  'BAKING SODA',
#  'GUAR GUM',
#  'KONJAC',
#  'XANTHAN GUM',
#  'ALL PURPOSE GF FLOUR',
#  'BROWN RICE FLOUR',
#  'POTATO FLOUR',
#  'TAPIOCA FLOUR',
#  'POTATO STARCH',
#  'WHITE RICE FLOUR',
#  'XANTHAN GUM',
#  '',
#  'ORGANIC CANE SUGAR',
#  'GLUTEN FREE OATS',
#  'VEGAN BUTTERY SPREAD',
#  '',
#  'OIL BLEND',
#  'PALM FRUIT',
#  'CANOLA',
#  'OLIVE',
#  '',
#  'WATER',
#  'SALT',
#  'NATURAL FLAVOR',
#  'SUNFLOWER LECITHIN',
#  'LACTIC ACID',
#  'ANNATTO EXTRACT',
#  '',
#  'ORGANIC BROWN SUGAR',
#  'WATER',
#  'TAPIOCA SYRUP',
#  'PALM FRUIT OIL',
#  'BAKING SODA',
#  'PURE VANILLA EXTRACT',
#  'WATER',
#  'VANILLA BEAN',
#  'ALCOHOL 40%',
#  '',
#  'SUNFLOWER LECITHIN',
#  'CREAM OF TARTAR',
#  'SPICE',
#  'KOSHER SALT',
#  'KONJAC',
#  'GUAR GUM',
#  'XANTHAN GUM',
#  'GLUTEN FREE FLOUR',
#  'TAPIOCA STARCH',
#  'BROWN RICE FLOUR',
#  '',
#  'EGGS',
#  'SUGAR',
#  'CANOLA OIL',
#  'BROWN SUGAR',
#  'WATER',
#  'BLUEBERRIES',
#  'BAKING POWDER',
#  'SODIUM ACID PYROPHOSPHATE',
#  'POTATO STARCH',
#  'MONOCALCIUM PHOSPHATE',
#  '',
#  'LECITHIN',
#  'NATURAL FLAVOR',
#  'XANTHAN GUM',
#  'SALT',
#  'SUNFLOWER OIL.',
#  'GLUTEN FREE FLOUR',
#  'TAPIOCA',
#  'WHITE RICE',
#  'SORGHUM',
#  'CORN',
#  '',
#  'PALM OIL',
#  'WATER',
#  'EGGS',
#  'SUGAR',
#  'SALT',
#  'XANTHAN GUM. BLUEBERRY  BLUEBERRIES',
#  'WATER',
#  'SUGAR',
#  'CORN SYRUP MODIFIED FOOD STARCH',
#  'VEGETABLE GUM',
#  'CITRIC ACID',
#  'VEGETABLE EXTRACT.',
#  'GLUTEN FREE FLOUR',
#  'TAPIOCA STARCH',
#  'WHITE RICE FLOUR',
#  'SORGHUM FLOUR',
#  'CORN STARCH',
#  '',
#  'PALM OIL',
#  'WATER',
#  'EGGS',
#  'SUGAR',
#  'SALT',
#  'XANTHAN GUM',
#  'CHERRY FILLING',
#  'CHERRIES',
#  'WATER',
#  'SUGAR',
#  'CORN SYRUP',
#  'MODIFIED FOOD STARCH',
#  'VEGETABLE GUM',
#  'CITRIC ACID',
#  'VEGETABLE EXTRACT',
#  '.',
#  'NON-GMO CONSTARCH',
#  'NON GMO POTATO STARCH',
#  'NON-GMO SORGHUM FLOUR',
#  'NON-GMO RICE FLOUR',
#  'NON-GMO POTATO FLOUR',
#  '',
#  'WATER',
#  'NON-GMO CORN OIL',
#  'CANE SUGAR',
#  'DRY YEAST',
#  'SALT',
#  'XANTHAN GUM',
#  'EXTRA VIRGIN OLIVE OIL. SAUCE',
#  'VINE-RIPENED FRESH TOMATOES',
#  'SALT',
#  'CALCIUM CHLORIDE',
#  'NATURALLY DERIVED CITRIC ACID PIZZA SAUCE',
#  'TOMATOES PUREE',
#  'TOMATOES',
#  'CANOLA OIL',
#  'SALT',
#  'IMPORTED PECORINO CHEESE',
#  "PASTEURIZED SHEEP'S MILK",
#  'CHEESE CULTURES',
#  'SEA SALT',
#  '',
#  'RENNET',
#  '',
#  'IMPORTED EXTRA VIRGIN OLIVE OIL',
#  'SPICES',
#  'GARLIC. WHOLE MILK MOZZARELLA CHEESE',
#  'PASTEURIZED MILK',
#  'CHEESE CULTURES',
#  'SALT',
#  'ENZYMES. ITALIAN SAUSAGE',
#  'PORK',
#  'SALT',
#  'NATURAL FLAVORING',
#  'DEXTROSE',
#  'GARLIC. NON GMO CORN OIL. PARMESAN CHEESE',
#  'PASTEURIZED PART-SKIM MILK',
#  'CHEESE CULTURES',
#  'SALT',
#  'ENZYMES',
#  '. OREGANO.',
#  'GLUTEN FREE FLOUR',
#  'TAPIOCA',
#  'WHITE RICE',
#  'CORN',
#  'SOY',
#  '',
#  'WATER',
#  'EGGS',
#  'PALM OIL',
#  'HONEY',
#  'BROWN SUGAR',
#  'XANTHAN GUM',
#  'SALT',
#  'DRY YEAST',
#  'APPLE CIDER VINEGAR',
#  'FLAX SEEDS.',
#  'ORGANIC POTATO',
#  'ALMOND FLOUR',
#  'CAGE-FREE EGG WHITES',
#  'SWEET POTATO FLOUR',
#  'SWEET POTATO JUICE',
#  'TAPIOCA FLOUR',
#  'CAGE-FREE EGGS',
#  'POTATO STARCH',
#  'SEA SALT',
#  'ANNATO SEED.',
#  'ALMOND FLOUR',
#  'CAGE-FREE EGGS',
#  'TAPIOCA FLOUR',
#  'XANTHAN GUM',
#  'SEA SALT.',
#  'BROWN RICE FLOUR',
#  'RICE FLOUR',
#  'POTATO STARCH',
#  'TAPIOCA FLOUR',
#  'BROWN SUGAR',
#  'NON-GMO CANOLA OIL',
#  'EGGS',
#  'POTATO FLOUR',
#  'YEAST',
#  'GUAR GUM',
#  'SEA SALT.',
#  'GLUTEN FREE FLOUR',
#  'WHITE RICE FLOUR',
#  'BROWN RICE FLOUR',
#  'POTATO STARCH',
#  'TAPIOCA FLOUR',
#  'XANTHAN GUM',
#  '',
#  'VANILLA CREAM',
#  'AGAVE',
#  'NATURAL VANILLA EXTRACT',
#  'SUGAR',
#  'ORGANIC PALM OIL',
#  'CORN SYRUP',
#  'WATER',
#  '',
#  'SUGAR',
#  'ORGANIC PALM OIL',
#  'WATER',
#  'EGG',
#  'COCOA',
#  'PROCESSED WITH ALKALI',
#  '',
#  'NATURAL VANILLA EXTRACT',
#  'CREAM OF TARTAR',
#  'AGAVE SYRUP',
#  'BAKING POWDER',
#  'SODIUM ACID PYROPHOSPHATE',
#  'SODIUM BICARBONATE',
#  'CORNSTARCH',
#  'MONOCALCIUM PHOSPHATE',
#  '',
#  'SALT',
#  'BAKING SODA.',
#  'GLUTEN FREE FLOUR',
#  'BROWN RICE FLOUR',
#  'POTATO STARCH',
#  'TAPIOCA FLOUR',
#  'XANTHAN GUM',
#  '',
#  'SUGAR',
#  'ORGANIC PALM OIL',
#  'EGG',
#  'CHOCOLATE DIP',
#  'SUGAR',
#  'SOYBEAN OIL',
#  'COCOA',
#  'CHOCOLATE LIQUOR',
#  'SALT',
#  'VANILLA EXTRACT',
#  '',
#  'BROWN SUGAR',
#  'COCONUT',
#  'VANILLA FLAVOR',
#  'AGAVE SYRUP',
#  'CREAM OF TARTAR',
#  'BAKING SODA',
#  'BAKING POWDER',
#  'SODIUM ACID PYROPHOSPHATE',
#  'SODIUM BICARBONATE',
#  'CORNSTARCH',
#  'MONOCALCIUM PHOSPHATE',
#  '',
#  'SALT.',
#  'GLUTEN-FREE BREAD',
#  'BROWN RICE FLOUR',
#  'TAPIOCA STARCH',
#  'POTATO STARCH',
#  'CANOLA OIL',
#  'PSYLLIUM POWDER',
#  'EGG WHITES',
#  'EVAPORATED CANE SUGAR',
#  'TEFF FLOUR',
#  'SEA SALT',
#  'FLAX SEED',
#  'YEAST',
#  'XANTHAN GUM',
#  'GUAR GUM.   CHICKEN BREAST',
#  'CHICKEN BREAST',
#  'WATER',
#  'RICE STARCH',
#  'CHILIES',
#  'SALT',
#  'SUGAR',
#  'PAPRIKA',
#  '',
#  'MONTEREY JACK CHEESE',
#  'PASTEURIZED MILK',
#  'CHEESE CULTURE',
#  'SALT',
#  'ENZYMES',
#  '',
#  'ALFREDO SAUCE',
#  'CREAM CHEESE',
#  'PASTEURIZED',
#  'CULTURED MILK',
#  'CREAM',
#  'SALT',
#  'STABILIZER',
#  'BLACK BEANS',
#  'BLACK BEANS',
#  'WATER',
#  'SALT',
#  '',
#  'CORN CHIPOTLE PUREE',
#  'WATER',
#  'VINEGAR',
#  'CHIPOTLE JALAPENO',
#  'TOMATO PASTE',
#  'SALT',
#  'RED CHILE FLAKES',
#  'SPICES',
#  'ONION POWDER',
#  'GARLIC POWDER',
#  '',
#  'POWDERED CELLULOSE',
#  'CORN STARCH.',
#  'MARINARA SAUCE',
#  'DICED TOMATO',
#  'TOMATOES',
#  'TOMATO JUICE',
#  'SALT',
#  'CITRIC ACID',
#  'CALCIUM CHLORIDE',
#  '',
#  'ONION',
#  'CHARDONNAY WINE',
#  'OLIVE CANOLA OIL BLEND',
#  'SUGAR',
#  'GARLIC',
#  'BASIL',
#  'SALT',
#  'BLACK PEPPER',
#  'RED PEPPER FLAKES',
#  'BAY LEAF',
#  '',
#  'FILLING',
#  'RICOTTA CHEESE',
#  'WHOLE MILK',
#  'WHEY',
#  'VINEGAR',
#  'SALT',
#  '',
#  'PARMESAN CHEESE',
#  'PASTEURIZED MILK',
#  'CULTURE',
#  'SALT',
#  'ENZYMES',
#  '',
#  'EGG',
#  'BASIL',
#  'OREGANO',
#  '',
#  'PASTA',
#  'BROWN RICE',
#  'RICE BRAN',
#  'WATER',
#  '',
#  'LOW-MOISTURE PART-SKIM MOZZARELLA',
#  'PROVOLONE CHEESE',
#  'PASTEURIZED REDUCED-FAT MILK',
#  'PASTEURIZED MILK CHEESE CULTURE',
#  'SALT',
#  'ENZYMES',
#  'POWDERED CELLULOSE ADDED TO PREVENT CAKING',
#  'NATURAL SMOKE FLAVOR',
#  'NATAMYCIN ADDED AS A MOLD INHIBITOR',
#  '.',
#  'MARINARA SAUCE',
#  'DICED TOMATO',
#  'ONION',
#  'WHITE WINE',
#  'OLIVE OIL',
#  'SUGAR',
#  'GARLIC',
#  'BASIL',
#  'SALT',
#  'IODIZED',
#  '',
#  'RED PEPPER FLAKES',
#  'BLACK PEPPER',
#  'BAY LEAVES',
#  '',
#  'DAIRY FREE CHEESE',
#  'FILTERED WATER',
#  'TAPIOCA',
#  '/OR ARROWROOT FLOURS',
#  'NON-GMO EXPELLER PRESSED CANOLA',
#  '/OR NON-GMO EXPELLER PRESSED SAFFLOWER OIL',
#  'COCONUT OIL',
#  'PEA PROTEIN',
#  'SALT',
#  'VEGAN NATURAL FLAVORS',
#  'INACTIVE YEAST',
#  'VEGETABLE GLYCERIN',
#  'XANTHUM GUM',
#  'CITRIC ACID',
#  'FLAVOR',
#  '',
#  '',
#  'LASAGNA NOODLES',
#  'RICE',
#  'RICE BRAN',
#  'WATER',
#  '',
#  'SPINACH',
#  'EGG',
#  'DRY BASIL',
#  'OREGANO',
#  'DRY GROUND',
#  '',
#  'WATER MODIFIED FOOD STARCH POTATO FLAKES SALT BROWN RICE FLOUR EGGS GUAR GUM XANTHAN GUM CAROB BEAN GUM MONO',
#  'DIGLYCERIDES LECITHIN RIBOFLAVIN',
#  'WATER',
#  'MODIFIED FOOD STARCH',
#  'POTATO FLAKES',
#  'SALT',
#  'BROWN RICE FLOUR',
#  'EGGS',
#  'GUAR GUM',
#  'XANTHAN GUM',
#  'CAROB BEAN GUM',
#  'MONO',
#  'DIGLYCERIDES',
#  'LECITHIN',
#  'RIBOFLAVIN',
#  'WHOLE MILK RICOTTA CHEESE',
#  'SWEET WHEY',
#  'WHOLE MILK',
#  'SWEET CREAM',
#  'CULTURE',
#  'VINEGAR',
#  'SALT',
#  '',
#  'ASIAGO CHEESE',
#  'PART SKIM MILK',
#  'CHEESE CULTURES',
#  'SALT',
#  '',
#  'ENZYMES',
#  '',
#  'RICE FLOUR',
#  'SALT',
#  'HALF & HALF',
#  'MILK',
#  'CREAM',
#  '',
#  'SALT',
#  'SPICE',
#  'CREAM CHEESE',
#  'PASTEURIZED MILK',
#  'CREAM',
#  'CHEESE CULTURE',
#  'SALT',
#  'STABILIZERS',
#  'CAROB BEAN',
#  '/OR XANTHAN',
#  '/OR GUAR GUMS',
#  '',
#  '',
#  'SUGAR',
#  'EGG',
#  'RICE FLOUR',
#  'BUTTER',
#  'TAPIOCA FLOUR',
#  'POTATO STARCH',
#  'BAKING POWDER',
#  'SODIUM PYROPHOSPHATE',
#  'SODIUM BICARBONATE',
#  'SODIUM MONOCALCIUM PHOSPHATE',
#  '',
#  'SALT',
#  'NATURAL FLAVORS',
#  'VANILLA',
#  'XANTHAN GUM',
#  'SUGAR',
#  'BUTTER',
#  'CREAM',
#  'NATURAL FLAVORING CHOCOLATE',
#  'COCOA MASS',
#  '',
#  'GLUTEN FREE ALL PURPOSE MIX',
#  'RICE FLOUR',
#  'CORN STARCH',
#  'TAPIOCA DEXTRIN',
#  'XANTHAN GUM',
#  'RICE EXTRACT',
#  '',
#  'PASTEURIZED EGGS',
#  'PASTEURIZED LIQUID EGG',
#  'WHOLE EGG',
#  'CITRIC ACID',
#  '0.1% WATER ADDED AS A CARRIER  CITRIC ACID',
#  '',
#  '/OR PASTEURIZED FRESH WHOLE EGG',
#  '',
#  'VANILLA BEAN',
#  'SUGAR',
#  'WATER',
#  'VANILLA EXTRACT',
#  'VANILLA BEANS',
#  'GUM TRAGACANTH',
#  '',
#  'SALT',
#  'PAN SPRAY',
#  'CANOLA OIL',
#  'ISOBUTENE',
#  'PROPANE',
#  'SOYA LECITHIN',
#  'DIMETHICONE',
#  '',
#  'CERTIFIED GLUTEN FREE OATS',
#  'BROWN SUGAR',
#  'DRIED CRANBERRIES',
#  '',
#  'SUGAR',
#  'GLYCERIN',
#  '',
#  'CITRIC ACID',
#  'SUNFLOWER OIL',
#  '',
#  'CINNAMON',
#  'GROUND FLAX',
#  'SALT',
#  '',
#  'CERTIFIED GLUTEN-FREE OATS',
#  'BROWN SUGAR',
#  'FREEZE-DRIED STRAWBERRIES',
#  'GROUND FLAX',
#  'SALT',
#  'RICE FLOUR',
#  'TAPIOCA STARCH',
#  'POTATO STARCH',
#  'NON-GMO CORN-STARCH ALUMINUM-FREE CORN-FREE BAKING POWDER',
#  'SODIUM ACID PYROPHOSPHATE',
#  'BAKING SODA',
#  'TAPIOCA STARCH',
#  'MONOCALCIUM PHOSPHATE',
#  '',
#  'XANTHAN GUM',
#  'STABILIZER',
#  '',
#  'SALT',
#  'NIACIN',
#  'VITAMIN B3',
#  '',
#  'REDUCED IRON',
#  'CALCIUM CARBONATE',
#  'THIAMIN MONONITRATE',
#  'VITAMIN B1',
#  '',
#  'RIBOFLAVIN',
#  'VITAMIN B2',
#  '',
#  'FOLIC ACID',
#  'VITAMIN B9',
#  '.',
#  'SUGAR',
#  'CHOCOLATE CHIPS',
#  'SUGAR',
#  'CHOCOLATE LIQUOR',
#  'COCOA BUTTER',
#  'SOY LECITHIN',
#  'VANILLA EXTRACT',
#  '',
#  'COCOA POWDER PROCESSED WITH ALKALI',
#  'POTATO STARCH',
#  'WHITE RICE FLOUR',
#  'CORN STARCH',
#  'SALT',
#  'XANTHAN GUM.',
#  'CERTIFIED GLUTEN-FREE OATS',
#  'CASHEWS',
#  'SALT',
#  '',
#  'DRIED CRANBERRIES',
#  'SUGAR',
#  'SUNFLOWER OIL',
#  '',
#  'BROWN SUGAR',
#  'CANOLA OIL',
#  'HONEY',
#  'FLAX SEEDS',
#  'VANILLA',
#  'CERTIFIED GLUTEN-FREE OATS',
#  'BROWN SUGAR',
#  'FREEZE DRIED BANANAS',
#  'MAPLE SUGAR',
#  'FLAX MEAL',
#  'SALT.',
#  'GLUTEN-FREE BREAD',
#  'WATER',
#  'BROWN RICE FLOUR',
#  'TAPIOCA STARCH',
#  'POTATO STARCH',
#  'CANOLA OIL',
#  'PSYLLIUM POWDER',
#  'EGG WHITES',
#  'EVAPORATED CANE SUGAR',
#  'TEFF FLOUR',
#  'SEA SALT',
#  'FLAX SEED',
#  'YEAST',
#  'XANTHAN GUM',
#  'GUAR GUM.',
#  'ROAST BEEF',
#  'BEEF',
#  'WATER',
#  'SALT',
#  '',
#  'PROVOLONE CHEESE',
#  'PASTEURIZED MILK',
#  'CHEESE CULTURE',
#  'SALT',
#  'ENZYMES',
#  '',
#  'ALFREDO SAUCE',
#  'CREAM CHEESE',
#  'PASTEURIZED',
#  'CULTURED MILK',
#  'CREAM',
#  'SALT',
#  'STABILIZER',
#  'XANTHAN GUM',
#  'OR CAROB BEAN',
#  'OR GUAR GUMS',
#  '',
#  '',
#  'CARAMELIZED ONIONS',
#  'ONIONS',
#  'CANOLA OIL',
#  'SUGAR',
#  'BALSAMIC VINEGAR',
#  '',
#  'POWDERED CELLULOSE',
#  'CORN STARCH.',
#  'GLUTEN-FREE FLOUR',
#  'TORTILLA',
#  'WHITE CORN MASA FLOUR',
#  'A TRACE OF LIME',
#  'WATER PREGELATINIZED RICE FOUR',
#  'POTATO FLOUR',
#  'HIGH OLEIC SAFFLOWER OIL',
#  'CORN STARCH',
#  'XANTHAN GUM',
#  '',
#  'MOZZARELLA CHEESE',
#  'PASTEURIZED PART-SKIM MILK',
#  'CHEESE CULTURES',
#  'SALT ENZYMES',
#  '',
#  'PIZZA SAUCE',
#  'VINE RIPENED FRESH TOMATOES',
#  'OLIVE OIL',
#  'SUNFLOWER OIL',
#  'SALT',
#  'SEASONINGS',
#  'GRANULATED GARLIC',
#  'CITRIC ACID',
#  '',
#  'RICE',
#  'CHEDDAR CHEESE',
#  'PASTEURIZED MILK',
#  'CHEESE CULTURES',
#  'SALT',
#  'ENZYMES',
#  'ANNATTO COLOR',
#  '',
#  'RICOTTA CHEESE',
#  'PASTEURIZED WHEY',
#  'PASTEURIZED MILK',
#  'VINEGAR',
#  'STABILIZER',
#  'MODIFIED FOOD STARCH',
#  'GUAR GUM',
#  'CARRAGEENAN',
#  '',
#  'SALT',
#  '',
#  'POWDERED CELLULOSE',
#  'MODIFIED FOOD STARCH',
#  'GARLIC SALT',
#  'SALT',
#  'GARLIC',
#  'GARLIC OIL',
#  '',
#  'OREGANO.',
#  'GLUTEN-FREE FLOUR TORTILLA',
#  'WHITE CORN MASA FLOUR',
#  'A TRACE OF LIME',
#  'WATER',
#  'PREGELANTINIZED RICE FLOUR',
#  'POTATO FLOUR',
#  'HIGH OLEIC SAFFLOWER OIL',
#  'CORN STARCH',
#  'XANTHAN GUM',
#  '',
#  'PIZZA SAUCE',
#  '',
#  'VINE RIPENED FRESH TOMATOES',
#  'OLIVE OIL',
#  'SUNFLOWER OIL',
#  'SALT',
#  'SEASONINGS',
#  'GRANULATED GARLIC',
#  'CITRIC ACID',
#  '',
#  'MOZZARELLA CHEESE',
#  'PASTEURIZED PART-SKIM MILK',
#  'CHEESE CULTURES',
#  'SALT',
#  'ENZYMES',
#  '',
#  'ITALIAN SAUSAGE',
#  'PORK',
#  'WATER',
#  'SPICES',
#  'SALT',
#  'SUGAR',
#  'FLAVORINGS',
#  '',
#  'RICE POWDERED CELLULOSE',
#  'MODIFIED FOOD STARCH',
#  'GARLIC SALT',
#  'SALT',
#  'GARLIC',
#  'CALCIUM SILICATE',
#  'GARLIC OIL',
#  '.',
#  'REFRIED BEANS',
#  'BEANS',
#  'WATER',
#  'CANOLA OIL',
#  'SALT',
#  '',
#  'RICE',
#  'CHEDDAR CHEESE',
#  'PASTEURIZED MILK',
#  'CHEESE CULTURES',
#  'SALT',
#  'ENZYMES',
#  'ANNATTO COLOR',
#  '',
#  'SALSA',
#  'TOMATOES',
#  'TOMATO JUICE',
#  'WATER',
#  'TOMATO CONCENTRATE',
#  'SALT',
#  'VITAMIN C',
#  '',
#  'ONIONS',
#  'BELL PEPPERS',
#  'PEPPERS',
#  'PARSLEY',
#  'GARLIC',
#  'CILANTRO',
#  'APPLE CIDER VINEGAR',
#  'SPICES',
#  'SEA SALT',
#  'HERBS',
#  '',
#  'CORN',
#  'SOUR CREAM',
#  'GRADE A CULTURED CREAM',
#  'MILK',
#  '',
#  'ENZYME',
#  '',
#  'GARLIC SALT',
#  'GARLIC',
#  'SALT',
#  'GARLIC OIL',
#  '. GLUTEN-FREE TORTILLA',
#  'WATER',
#  'WHITE CORN MASA FLOUR',
#  'TRACE OF LIME',
#  '',
#  'PREGELATINIZED RICE FLOUR',
#  'POTATO STARCH',
#  'HIGH OLEIC SAFFLOWER OIL',
#  'CORN STARCH',
#  'XANTHAN GUM.',
#  'GLUTEN-FREE FLOUR TORTILLA',
#  'WHITE CORN MASA FLOUR',
#  'A TRACE OF LIME',
#  'WATER',
#  'PREGELATINIZED RICE FLOUR',
#  'POTATO FLOUR',
#  'HIGH OLEIC SAFFLOWER OIL',
#  'CORN STARCH',
#  'XANTHAN GUM',
#  'CULTURED DEXTROSE',
#  '',
#  'REFRIED BEANS',
#  'BEANS',
#  'WATER',
#  'CANOLA OIL',
#  'SALT',
#  '',
#  'RICE',
#  'SALSA',
#  'TOMATOES',
#  'TOMATO JUICE',
#  '',
#  'WATER',
#  'TOMATO CONCENTRATE',
#  'SALT',
#  'VITAMIN C',
#  '',
#  'ONIONS',
#  'BELL PEPPERS',
#  'PEPPERS',
#  'PARSLEY',
#  'GARLIC',
#  'CILANTRO',
#  'APPLE CIDER VINEGAR',
#  'SPICES',
#  'SEA SALT',
#  'HERBS',
#  '',
#  'TOFU',
#  'WATER',
#  'SOYBEANS',
#  'CALCIUM SULFATE',
#  '',
#  'GMO FREE CORN',
#  'GARLIC SALT',
#  'GARLIC',
#  'SALT',
#  'GARLIC OIL',
#  '.',
#  'GLUTEN FREE BREAD',
#  'WATER',
#  'BROWN RICE FLOUR',
#  'TAPIOCA STARCH',
#  'POTATO STARCH',
#  'CANOLA OIL',
#  'PSYLLIUM POWDER',
#  'EGG WHITES',
#  'ORGANIC EVAPORATED CANE SUGAR',
#  'TEFF FLOUR',
#  'SEA SALT',
#  'FLAX SEED',
#  'YEAST',
#  'XANTHAN GUM',
#  'GUAR GUM.   UNCURED HICKORY SMOKED HAM. NO NITRATES OR NITRATES ADDED EXCEPT THOSE NATURALLY OCCURRING IN SEA SALT',
#  'NATURAL FLAVORINGS',
#  'CELERY POWDER.',
#  'HAM',
#  'WATER',
#  'HONEY',
#  'SEA SALT',
#  'NATURAL FLAVORINGS',
#  'TURBINADO SUGAR',
#  'CELERY POWDER',
#  'SODIUM CARBONATE',
#  '',
#  'ALFREDO SAUCE',
#  'CREAM CHEESE',
#  'PASTEURIZED',
#  'CULTURED MILK',
#  '',
#  'CREAM',
#  'SALT',
#  'STABILIZER',
#  'XANTHAN GUM',
#  'OR CAROB BEAN',
#  'OR GUAR GUMS',
#  '',
#  '',
#  'PASTEURIZED CREAM',
#  'MILK',
#  '',
#  'UNSALTED BUTTER',
#  'CREAM',
#  '',
#  'MILK',
#  '',
#  'NATURAL FLAVOR',
#  '',
#  'SEA SALT',
#  'GARLIC POWDER',
#  'BLACK PEPPER',
#  '',
#  'CHEDDAR CHEESE PASTEURIZED MILK',
#  'CHEESE CULTURE',
#  'SALT',
#  'ENZYMES',
#  'ANNATTO',
#  'COLOR',
#  '',
#  '',
#  'MONTEREY JACK CHEESE',
#  'PASTEURIZED MILK',
#  'CHEESE CULTURE',
#  'SALT',
#  'ENZYMES',
#  '',
#  'POWDERED CELLULOSE',
#  'CORN STARCH.',
#  'MARINARA SAUCE',
#  'DICED TOMATO',
#  'TOMATOES',
#  'TOMATO JUICE',
#  'SALT',
#  'CITRIC ACID',
#  'CALCIUM CHLORIDE',
#  '',
#  'ONION',
#  'CHARDONNAY WINE',
#  'OLIVE CANOLA OIL BLEND',
#  'SUGAR',
#  'GARLIC',
#  'BASIL',
#  'SALT',
#  'BLACK PEPPER',
#  'RED PEPPER FLAKES',
#  'BAY LEAF',
#  '',
#  'FILLING',
#  'RICOTTA CHEESE',
#  'WHOLE MILK',
#  'WHEY',
#  'VINEGAR',
#  'SALT',
#  '',
#  'PARMESAN CHEESE',
#  'PASTEURIZED MILK',
#  'CULTURE',
#  'SALT',
#  'ENZYMES',
#  '',
#  'EGG',
#  'BASIL',
#  'OREGANO',
#  '',
#  'PASTA',
#  'BROWN RICE',
#  'RICE BRAN',
#  'WATER',
#  '',
#  'SPINACH',
#  'LOW-MOISTURE PART-SKIM MOZZARELLA',
#  'PROVOLONE CHEESE',
#  'PASTEURIZED REDUCED-FAT MILK',
#  'PASTEURIZED MILK CHEESE CULTURE',
#  'SALT',
#  'ENZYMES',
#  'POWDERED CELLULOSE ADDED TO PREVENT CAKING',
#  'NATURAL SMOKE FLAVOR',
#  'NATAMYCIN ADDED AS A MOLD INHIBITOR',
#  '.',
#  'WHOLE GRAIN BROWN RICE FLOUR',
#  'MODIFIED TAPIOCA STARCH',
#  'EGGS',
#  'XANTHAN GUM',
#  'SALT',
#  'WATER.  WHOLE MILK RICOTTA CHEESE',
#  'SWEET WHEY',
#  'WHOLE MILK',
#  'SWEET CREAM',
#  'CULTURE',
#  'VINEGAR',
#  'SALT',
#  '',
#  ...]

# %% [markdown]
# -----

# %%
# finding out how many indredients are in the file
len(clean_data_stripped)
# Out:
# 17592

# %% [markdown]
# Adding the data back into the dataset

# %% [markdown]
# -----

# %%
gf_df = pd.DataFrame(clean_data_stripped, columns=['ingredients'])
gf_df.head(6)
# Out:
#             ingredients
# 0  ALL PURPOSE GF FLOUR
# 1      BROWN RICE FLOUR
# 2          POTATO FLOUR
# 3         TAPIOCA FLOUR
# 4         POTATO STARCH
# 5      WHITE RICE FLOUR

# %% [markdown]
# Process of removing duplicates

# %%
gf_df.shape
# Out:
# (17592, 1)

# %%
gf_df.duplicated().sum()
# Out:
# 16486

# %%
# Check in terms of percentages
gf_df.duplicated().sum()/gf_df.shape[0]*100
# Out:
# 93.71305138699408

# %%
clean_data = gf_df.drop_duplicates()

# %%
clean_data.shape

# %%
clean_data.value_counts()

# %%
clean_data_stripped = [item.strip() for item in clean_data]

# %%
clean_data_stripped

# %% [markdown]
# -------
#
# -----

# %%
df1 = 

try:
    df1 = pd.read_csv('Gluten-freeDF.csv', encoding='utf-8')
except UnicodeDecodeError:
    try:
        df1 = pd.read_csv('Gluten-freeDF.csv', encoding='latin1')
    except UnicodeDecodeError:
        df1 = pd.read_csv('Gluten-freeDF.csv', encoding='ISO-8859-1')
